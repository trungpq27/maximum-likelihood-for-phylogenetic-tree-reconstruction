# %%
from Bio import SeqIO
import glob
import re

# %%
#create list of reference genbank files
gb_files = glob.glob("data/genbank/*.gb")
gb_files
# Out:
# ['data/genbank/Enterobacteria_phage_UAB_Phi87.gb',
#  'data/genbank/Enterobacteria_phage_WV8_complete_genome.gb',
#  'data/genbank/Escherichia_coli_O157_typing_phage_1_complete_genome.gb',
#  'data/genbank/Escherichia_phage vB_EcoM_ASO1A_complete_genome.gb',
#  'data/genbank/Escherichia_phage_EC6_complete_genome.gb',
#  'data/genbank/Escherichia_phage_HY02_complete_genome.gb',
#  'data/genbank/Escherichia_phage_JH2_complete_genome.gb',
#  'data/genbank/Escherichia_phage_vB_EcoM_Alf5_complete_genome.gb',
#  'data/genbank/Escherichia_phage_vB_EcoM_ASO1B_complete_genome.gb',
#  'data/genbank/Escherichia_phage_vB_EcoM_AYO145A_complete_genome.gb',
#  'data/genbank/Escherichia_phage_vB_EcoM_VpaE1_complete_genome.gb',
#  'data/genbank/Salmonella_phage_BPS15Q2_complete_genome.gb',
#  'data/genbank/Salmonella_phage_BPS17L1_complete_genome.gb',
#  'data/genbank/Salmonella_phage_BPS17W1_complete_genome.gb',
#  'data/genbank/Salmonella_phage_Mushroom_complete_genome.gb',
#  'data/genbank/Salmonella_phage_vB_SPuM_SP116_complete_genome.gb']

# %%
## grab coding regions from genbank - and translate
for file in gb_files:
    infile= file
    outfile = 'data/faa/' + infile.split('/')[-1].split('.')[0] + '.faa'
    input_handle  = open(infile, "r")
    output_handle = open(outfile, "w")
    file_name = infile.split('.')[0]
    
    for seq_record in SeqIO.parse(input_handle, "genbank") :
        print("Dealing with GenBank record %s" % file_name)
        output_handle.write('>' + file_name + '\n')
        for seq_feature in seq_record.features :
            if seq_feature.type=="CDS" :
                assert len(seq_feature.qualifiers['translation'])==1
                output_handle.write(
                   seq_feature.qualifiers['translation'][0])
        output_handle.write('\n')

    output_handle.close()
    input_handle.close()
# Out:
# Dealing with GenBank record data/genbank/Enterobacteria_phage_UAB_Phi87
# Dealing with GenBank record data/genbank/Enterobacteria_phage_WV8_complete_genome
# Dealing with GenBank record data/genbank/Escherichia_coli_O157_typing_phage_1_complete_genome
# Dealing with GenBank record data/genbank/Escherichia_phage vB_EcoM_ASO1A_complete_genome
# Dealing with GenBank record data/genbank/Escherichia_phage_EC6_complete_genome
# Dealing with GenBank record data/genbank/Escherichia_phage_HY02_complete_genome
# Dealing with GenBank record data/genbank/Escherichia_phage_JH2_complete_genome
# Dealing with GenBank record data/genbank/Escherichia_phage_vB_EcoM_Alf5_complete_genome
# Dealing with GenBank record data/genbank/Escherichia_phage_vB_EcoM_ASO1B_complete_genome
# Dealing with GenBank record data/genbank/Escherichia_phage_vB_EcoM_AYO145A_complete_genome
# Dealing with GenBank record data/genbank/Escherichia_phage_vB_EcoM_VpaE1_complete_genome
# Dealing with GenBank record data/genbank/Salmonella_phage_BPS15Q2_complete_genome
# Dealing with GenBank record data/genbank/Salmonella_phage_BPS17L1_complete_genome
# Dealing with GenBank record data/genbank/Salmonella_phage_BPS17W1_complete_genome
# Dealing with GenBank record data/genbank/Salmonella_phage_Mushroom_complete_genome
# Dealing with GenBank record data/genbank/Salmonella_phage_vB_SPuM_SP116_complete_genome

# %%
##combine faa files into one
# !cat data/faa/*.faa > data/aa_seqs.fasta

# %%
##MSA
from Bio.Align.Applications import ClustalOmegaCommandline
in_file = "data/aa_seqs.fasta"
out_file = "data/aa_seqs_omega_aln.fasta"
clustalomega_cline = ClustalOmegaCommandline(infile=in_file, outfile=out_file, verbose=True, auto=True, 
                                            distmat_out=True, percentid=True, distmat_full=True)
print(clustalomega_cline)
# Out:
# clustalo -i data/aa_seqs.fasta --distmat-out True --full --percent-id -o data/aa_seqs_omega_aln.fasta --auto -v

# %%
# #Run and Time MSA algorithm
# import time

# start_time = time.time()

# clustalomega_cline()

# end_time = time.time()
# execution_time = end_time - start_time
# print("Execution time:", execution_time, "seconds")

# %%
# !clustalo -i data/aa_seqs.fasta --distmat-out True --full --percent-id -o data/aa_seqs_omega_aln.fasta --auto -v
# Out:
# Using 16 threads
# Read 16 sequences (type: Protein) from data/aa_seqs.fasta
# not more sequences (16) than cluster-size (100), turn off mBed
# Setting options automatically based on input sequence characteristics (might overwrite some of your options).
# Auto settings: Enabling mBed.
# Auto settings: Setting iteration to 1.
# Using 15 seeds (chosen with constant stride from length sorted seqs) for mBed (from a total of 16 sequences)
# Calculating pairwise ktuple-distances...
# Ktuple-distance calculation progress done. CPU time: 100.49u 0.07s 00:01:40.55 Elapsed: 00:00:47
# mBed created 1 cluster/s (with a minimum of 1 and a soft maximum of 100 sequences each)
# Distance calculation within sub-clusters done. CPU time: 96.94u 0.02s 00:01:36.96 Elapsed: 00:00:45
# Guide-tree computation (mBed) done.
# Ignoring request to write distance matrix (am in mBed mode)
# Progressive alignment progress done. CPU time: 754.90u 32.63s 00:13:07.53 Elapsed: 00:08:54
# Iteration step 1 out of 1
# Computing new guide tree (iteration step 0)
# Calculating pairwise aligned identity distances...
# Pairwise distance matrix written to True172 % (234 out of 136)
# Pairwise identity calculation progress done. CPU time: 0.15u 0.00s 00:00:00.15 Elapsed: 00:00:00
# Guide-tree computation done.
# Computing HMM from alignment
# Progressive alignment progress done. CPU time: 2677.79u 121.44s 00:46:39.23 Elapsed: 00:37:25
# Alignment written to data/aa_seqs_omega_aln.fasta

# %%
##double check fasta formatting for alignment
SeqIO.parse('data/aa_seqs_omega_aln.fasta', "fasta")

# %%
##check if the number of nucleotide are equal
# !awk '/^>/{if (l!="") print l; print; l=0; next}{l+=length($0)}END{print l}' data/aa_seqs_omega_aln.fasta |paste - -
# Out:
# >data/genbank/Enterobacteria_phage_UAB_Phi87	45694
# >data/genbank/Enterobacteria_phage_WV8_complete_genome	45694
# >data/genbank/Escherichia_coli_O157_typing_phage_1_complete_genome	45694
# >data/genbank/Escherichia_phage_EC6_complete_genome	45694
# >data/genbank/Escherichia_phage_HY02_complete_genome	45694
# >data/genbank/Escherichia_phage_JH2_complete_genome	45694
# >data/genbank/Escherichia_phage_vB_EcoM_Alf5_complete_genome	45694
# >data/genbank/Escherichia_phage vB_EcoM_ASO1A_complete_genome	45694
# >data/genbank/Escherichia_phage_vB_EcoM_ASO1B_complete_genome	45694
# >data/genbank/Escherichia_phage_vB_EcoM_AYO145A_complete_genome	45694
# >data/genbank/Escherichia_phage_vB_EcoM_VpaE1_complete_genome	45694
# >data/genbank/Salmonella_phage_BPS15Q2_complete_genome	45694
# >data/genbank/Salmonella_phage_BPS17L1_complete_genome	45694
# >data/genbank/Salmonella_phage_BPS17W1_complete_genome	45694
# >data/genbank/Salmonella_phage_Mushroom_complete_genome	45694
# >data/genbank/Salmonella_phage_vB_SPuM_SP116_complete_genome	45694

# %% [markdown]
# ## Running Command line Tool - RaXml

# %%
# !./bin/modeltest-ng --help
# Out:
#                              _      _ _            _      _   _  _____
#                             | |    | | |          | |    | \ | |/ ____|
#          _ __ ___   ___   __| | ___| | |_ ___  ___| |_   |  \| | |  __
#         | '_ ` _ \ / _ \ / _` |/ _ \ | __/ _ \/ __| __|  | . ` | | |_ |
#         | | | | | | (_) | (_| |  __/ | ||  __/\__ \ |_   | |\  | |__| |
#         |_| |_| |_|\___/ \__,_|\___|_|\__\___||___/\__|  |_| \_|\_____|
# --------------------------------------------------------------------------------
# ModelTest-NG v0.1.7 released on 17.03.2021 by The Exelixis Lab.
# Written by Diego Darriba.
# Contributors: Tomas Flouri, Alexey Kozlov, Benoit Morel, David Posada,
#               Alexandros Stamatakis.
# Latest version: https://github.com/ddarriba/modeltest
# --------------------------------------------------------------------------------
#
# Usage: modeltest-ng -i sequenceFilename
#             [-c n_categories] [-d nt|aa] [-F] [-N]
#             [-p numberOfThreads] [-q partitionsFile]
#             [-t mp|fixed|user] [-u treeFile] [-v] [-V]
#             [-T raxml|phyml|mrbayes|paup]
#             [--eps optimizationEpsilonValue] [--tol parameterTolerance]
#
# selects the best-fit model of amino acid or nucleotide replacement.
#
# mandatory arguments for long options are also mandatory for short options.
#
#
#  Main arguments:
#   -d, --datatype data_type_t            sets the data type
#                  nt                     nucleotide
#                  aa                     amino acid
#   -i, --input input_msa                 sets the input alignment file (FASTA or PHYLIP format, required)
#   -o, --output output_file              pipes the output into a file
#   -p, --processes n_procs               sets the number of processors to use (shared memory)
#   -q, --partitions partitions_file      sets a partitioning scheme
#   -r, --rngseed seed                    sets the seed for the random number generator
#   -t, --topology type                   sets the starting topology
#                  ml                     maximum likelihood
#                  mp                     maximum parsimony
#                  fixed-ml-jc            fixed maximum likelihood (JC)
#                  fixed-ml-gtr           fixed maximum likelihood (GTR)
#                  fixed-mp               fixed maximum parsimony (default)
#                  random                 random generated tree
#                  user                   fixed user defined (requires -u argument)
#   -u, --utree tree_file                 sets a user tree
#       --force                           force output overriding
#       --disable-checkpoint              disable checkpoint writing
#
#  Candidate models:
#   -a, --asc-bias algorithm[:values]     includes ascertainment bias correction
#                                           check modeltest manual for more information
#                  lewis                  Lewis (2001)
#                  felsenstein            Felsenstein
#                                           requires number of invariant sites
#                  stamatakis             Leaché et al. (2015)
#                                           requires invariant sites composition
#   -f, --frequencies [ef]                sets the candidate models frequencies
#                                         e: estimated - maximum likelihood (DNA) / empirical (AA)
#                                         f: fixed - equal (DNA) / model defined (AA)
#   -h, --model-het [uigf]                sets the candidate models rate heterogeneity
#                                         u: *uniform
#                                         i: *proportion of invariant sites (+I)
#                                         g: *discrite Gamma rate categories (+G)
#                                         f: *both +I and +G (+I+G)
#                                         r: free rate models (+R)
#                                         * included by default
#   -m, --models list                     sets the candidate model matrices separated by commas.
#                                         use '+' or '-' prefix for updating the default list.
#                                         e.g., "-m JTT,LG" evaluates JTT and LG only .
#                                               "-m +LG4X,+LG4M,-LG" adds LG4 models and removes LG and from the list.
#                                         dna: *JC *HKY *TrN *TPM1 *TPM2 *TPM3
#                                              *TIM1 *TIM2 *TIM3 *TVM *GTR
#                                         protein: *DAYHOFF *LG *DCMUT *JTT *MTREV *WAG *RTREV *CPREV
#                                                  *VT *BLOSUM62 *MTMAM *MTART *MTZOA *PMB *HIVB *HIVW
#                                                  *JTT-DCMUT *FLU *STMTREV LG4M LG4X GTR
#                                         * included by default
#   -s, --schemes [3|5|7|11|203]          sets the number of predefined DNA substitution schemes evaluated
#                                         3:   JC/F81, K80/HKY, SYM/GTR
#                                         5:   + TrNef/TrN, TPM1/TPM1uf
#                                         7:   + TIM1ef/TIM1, TVMef/TVM
#                                         11:  + TPM2/TPM2uf, TPM3/TPM3uf, TIM2ef/TIM2, TIM3ef/TIM3
#                                         203: All possible GTR submatrices
#   -T, --template [tool]                 sets candidate models according to a specified tool
#                  raxml                  RAxML (DNA 3 schemes / AA full search)
#                  phyml                  PhyML (DNA full search / 14 AA matrices)
#                  mrbayes                MrBayes (DNA 3 schemes / 8 AA matrices)
#                  paup                   PAUP* (DNA full search / AA full search)
#
#  Other options:
#       --eps epsilon_value               sets the model optimization epsilon
#       --tol tolerance_value             sets the parameter optimization tolerance
#       --smooth-frequencies              forces frequencies smoothing
#   -g, --gamma-rates [a|g]               sets gamma rates mode
#                      a                  uses the average (or mean) per category (default)
#                      m                  uses the median per category
#       --disable-checkpoint              does not create checkpoint files
#   -H, --no-compress                     disables pattern compression
#                                         modeltest-ng ignores if there are missing states
#   -k, --keep-params                     keep branch lengths fixed
#   -v, --verbose                         run in verbose mode
#       --help                            display this help message and exit
#       --version                         output version information and exit
#
# Exit status:
#  0  if OK,
#  1  if minor problems (e.g., invalid arguments or data),
#  2  if serious trouble (e.g., execution crashed).
#
# Report modeltest-ng bugs to diego.darriba@h-its.org
# ModelTest home page: <http://www.github.com/ddarriba/modeltest/>

# %%
# !./bin/modeltest-ng -i data/aa_seqs_omega_aln.fasta -d aa -p 16
# Out:
#                              _      _ _            _      _   _  _____
#                             | |    | | |          | |    | \ | |/ ____|
#          _ __ ___   ___   __| | ___| | |_ ___  ___| |_   |  \| | |  __
#         | '_ ` _ \ / _ \ / _` |/ _ \ | __/ _ \/ __| __|  | . ` | | |_ |
#         | | | | | | (_) | (_| |  __/ | ||  __/\__ \ |_   | |\  | |__| |
#         |_| |_| |_|\___/ \__,_|\___|_|\__\___||___/\__|  |_| \_|\_____|
# --------------------------------------------------------------------------------
# ModelTest-NG v0.1.7 released on 17.03.2021 by The Exelixis Lab.
# Written by Diego Darriba.
# Contributors: Tomas Flouri, Alexey Kozlov, Benoit Morel, David Posada,
#               Alexandros Stamatakis.
# Latest version: https://github.com/ddarriba/modeltest
# --------------------------------------------------------------------------------
#
# Physical cores: 8
# Logical cores:  16
# Memory:         15GB
# Extensions:     AVX
#
# WARNING: MSA has not enough sites to infer reliable results
# Creating new checkpoint file: data/aa_seqs_omega_aln.fasta.ckp
# --------------------------------------------------------------------------------
# ModelTest-NG v0.1.7
#
# Input data:
#   MSA:        data/aa_seqs_omega_aln.fasta
#   Tree:       Maximum parsimony
#     file:           -
#   #taxa:            16
#   #sites:           45694
#   #patterns:        16193
#   Max. thread mem:  585 MB
#
# Output:
#   Log:           data/aa_seqs_omega_aln.fasta.log
#   Starting tree: data/aa_seqs_omega_aln.fasta.tree
#   Results:       data/aa_seqs_omega_aln.fasta.out
#
# Selection options:
#   # protein matrices: 19
#   # protein models:   152
#   include model parameters:
#     Uniform:         true
#     p-inv (+I):      true
#     gamma (+G):      true
#     both (+I+G):     true
#     free rates (+R): false
#     fixed freqs:     true
#     estimated freqs: false
#     #categories:     4
#   gamma rates mode:   mean
#   asc bias:           none
#   epsilon (opt):      0.01
#   epsilon (par):      0.05
#   keep branches:      false
#
# Additional options:
#   verbosity:        very low
#   threads:          16/8
#   RNG seed:         12345
#   subtree repeats:  enabled
# --------------------------------------------------------------------------------
# modeltest-ng was called as follows:
# >> ./bin/modeltest-ng -i data/aa_seqs_omega_aln.fasta -d aa -p 16
#
#
# Partition 1/1
#
#    12/152  MTMAM+I+G4+F   0h:01:34   0h:01:43         -343294.7436  1.1806  0.0216
#    13/152  MTART+I+G4+F   0h:01:58   0h:02:07         -339944.8340  1.2033  0.0216
#    14/152  MTZOA+I+G4+F   0h:02:07   0h:02:16         -335454.5480  1.3780  0.0216
#     7/152  MTREV+I+G4+F   0h:02:25   0h:02:34         -333644.0643  1.2317  0.0216
#    17/152  FLU+I+G4+F     0h:02:26   0h:02:35         -334176.7859  1.2317  0.0216
#    15/152  HIVW+I+G4+F    0h:02:42   0h:02:51         -338960.6771  1.1143  0.0216
#     3/152  DAYHOFF+I+G4+F 0h:02:55   0h:03:04         -331235.4087  1.2520  0.0216
#     5/152  DCMUT+I+G4+F   0h:02:59   0h:03:08         -331199.5520  1.2059  0.0216
#    16/152  STMTREV+I+G4+F 0h:03:04   0h:03:13         -335186.8451  1.1758  0.0216
#    10/152  CPREV+I+G4+F   0h:03:09   0h:03:18         -329436.9718  1.2139  0.0216
#     4/152  LG+I+G4+F      0h:03:16   0h:03:25         -329599.5898  1.2317  0.0216
#     9/152  RTREV+I+G4+F   0h:03:20   0h:03:29         -329876.2803  1.2719  0.0216
#     6/152  JTT+I+G4+F     0h:03:27   0h:03:36         -328803.1795  1.2301  0.0216
#     8/152  WAG+I+G4+F     0h:03:54   0h:04:03         -328020.1628  1.2458  0.0216
#    11/152  VT+I+G4+F      0h:04:33   0h:04:42         -326801.9876  1.1519  0.0216
#     2/152  BLOSUM62+I+G4+F0h:04:44   0h:04:53         -327621.2108  1.1303  0.0216
#    21/152  HIVB+G4+F      0h:02:19   0h:04:53         -335545.3343  1.1076       -
#    19/152  HIVB+I+G4+F    0h:02:58   0h:05:05         -335587.3680  1.1397  0.0216
#    25/152  FLU+G4+F       0h:02:00   0h:05:08         -334135.5726  1.1437       -
#    22/152  LG+G4+F        0h:02:34   0h:05:09         -329542.7479  1.1684       -
#    27/152  MTREV+G4+F     0h:01:56   0h:05:14         -333606.3440  1.1580       -
#    18/152  JTT-DCMUT+I+G4+F0h:03:33   0h:05:16         -328826.4165  1.2317  0.0216
#    23/152  STMTREV+G4+F   0h:02:28   0h:05:19         -335145.1198  1.1146       -
#    28/152  HIVW+G4+F      0h:02:10   0h:05:35         -338921.1682  1.0714       -
#    29/152  DAYHOFF+G4+F   0h:02:16   0h:05:45         -331174.7655  1.1349       -
#    26/152  JTT-DCMUT+G4+F 0h:02:40   0h:05:53         -328768.7712  1.1452       -
#    24/152  WAG+G4+F       0h:03:01   0h:06:05         -327944.5585  1.1300       -
#    31/152  CPREV+G4+F     0h:02:25   0h:06:28         -329379.1979  1.1082       -
#    40/152  MTMAM+I+G4     0h:01:13   0h:06:32         -361532.1527  1.1730  0.0216
#    34/152  MTZOA+G4+F     0h:01:42   0h:06:35         -335434.7165  1.1791       -
#    38/152  MTMAM+G4+F     0h:01:21   0h:06:35         -343285.7188  1.1200       -
#    36/152  MTART+G4+F     0h:01:34   0h:06:42         -339925.9320  1.1248       -
#    20/152  PMB+I+G4+F     0h:04:44   0h:07:00         -327361.1187  1.1212  0.0216
#    30/152  BLOSUM62+G4+F  0h:03:41   0h:07:17         -327536.2577  1.0815       -
#    37/152  DCMUT+G4+F     0h:02:18   0h:07:27         -331140.4035  1.1331       -
#    35/152  JTT+G4+F       0h:02:43   0h:07:48         -328745.4610  1.1421       -
#    39/152  RTREV+G4+F     0h:02:36   0h:07:52         -329814.2925  1.1038       -
#    47/152  MTART+I+G4     0h:01:17   0h:07:52         -358098.7079  1.2080  0.0216
#    48/152  MTZOA+I+G4     0h:01:30   0h:08:05         -351340.3912  1.3538  0.0216
#    46/152  MTREV+I+G4     0h:01:50   0h:08:22         -350455.5468  1.2971  0.0216
#    33/152  VT+G4+F        0h:03:31   0h:08:24         -326719.7971  1.0977       -
#    32/152  PMB+G4+F       0h:03:42   0h:08:24         -327274.0396  1.0763       -
#    59/152  DAYHOFF+I+F    0h:00:25   0h:08:49         -333985.3204       -  0.0780
#    41/152  CPREV+I+G4     0h:03:28   0h:09:03         -331725.3063  1.1509  0.0216
#    60/152  STMTREV+I+F    0h:00:27   0h:09:16         -337853.3783       -  0.0909
#    42/152  RTREV+I+G4     0h:03:38   0h:09:23         -333650.8386  1.2032  0.0216
#    61/152  FLU+I+F        0h:00:22   0h:09:25         -336831.9819       -  0.0803
#    62/152  JTT-DCMUT+I+F  0h:00:25   0h:09:41         -331226.0451       -  0.0760
#    63/152  HIVW+I+F       0h:00:21   0h:09:44         -342287.7705       -  0.0913
#    64/152  HIVB+I+F       0h:00:25   0h:09:50         -338698.7254       -  0.0863
#    65/152  PMB+I+F        0h:00:25   0h:10:06         -329990.0537       -  0.0698
#    66/152  VT+I+F         0h:00:24   0h:10:08         -329346.9835       -  0.0707
#    67/152  MTREV+I+F      0h:00:21   0h:10:11         -336046.5754       -  0.0760
#    44/152  WAG+I+G4       0h:04:17   0h:10:22         -329265.1782  1.1452  0.0216
#    68/152  WAG+I+F        0h:00:22   0h:10:28         -330561.1258       -  0.0720
#    52/152  HIVW+I+G4      0h:03:07   0h:10:34         -344831.6606  1.0747  0.0216
#    69/152  RTREV+I+F      0h:00:26   0h:10:34         -332431.5179       -  0.0753
#    70/152  CPREV+I+F      0h:00:24   0h:10:35         -331949.0260       -  0.0748
#    49/152  JTT+I+G4       0h:03:54   0h:10:36         -330334.9311  1.2604  0.0216
#    55/152  FLU+I+G4       0h:02:46   0h:10:38         -336316.3684  1.1734  0.0216
#    43/152  VT+I+G4        0h:04:45   0h:10:38         -328066.7675  1.1323  0.0216
#    71/152  JTT+I+F        0h:00:25   0h:10:47         -331204.4050       -  0.0762
#    74/152  MTMAM+I+F      0h:00:14   0h:10:48         -346304.5466       -  0.0885
#    51/152  HIVB+I+G4      0h:03:33   0h:10:50         -338647.4078  1.1096  0.0216
#    75/152  MTART+I+F      0h:00:17   0h:10:52         -342679.4154       -  0.0844
#    72/152  DCMUT+I+F      0h:00:25   0h:10:53         -333963.6924       -  0.0780
#    53/152  DCMUT+I+G4     0h:03:06   0h:10:54         -333872.9206  1.1304  0.0216
#    77/152  MTZOA+I+F      0h:00:18   0h:10:56         -337628.8177       -  0.0796
#    73/152  BLOSUM62+I+F   0h:00:24   0h:10:58         -330235.1292       -  0.0702
#    76/152  LG+I+F         0h:00:22   0h:10:58         -331992.8715       -  0.0802
#    45/152  BLOSUM62+I+G4  0h:05:00   0h:11:28         -328971.1759  1.1053  0.0216
#    56/152  STMTREV+I+G4   0h:03:24   0h:11:29         -342864.2932  1.1308  0.0216
#    58/152  DAYHOFF+I+G4   0h:03:09   0h:11:33         -333902.7778  1.1323  0.0216
#    54/152  JTT-DCMUT+I+G4 0h:03:45   0h:11:37         -330316.9626  1.2578  0.0216
#    85/152  MTMAM+G4       0h:00:56   0h:11:52         -361555.0581  1.0989       -
#    57/152  LG+I+G4        0h:03:34   0h:11:56         -330795.3863  1.2914  0.0216
#    87/152  MTART+G4       0h:01:04   0h:12:02         -358091.9614  1.1408       -
#    50/152  PMB+I+G4       0h:05:19   0h:12:19         -329418.1734  1.0892  0.0216
#    89/152  MTZOA+G4       0h:01:12   0h:12:41         -351337.1918  1.2317       -
#    82/152  FLU+G4         0h:02:08   0h:13:00         -336273.0114  1.1295       -
#    78/152  DAYHOFF+G4     0h:02:28   0h:13:06         -333840.7177  1.0230       -
#    86/152  HIVW+G4        0h:02:14   0h:13:12         -344795.8051  1.0000       -
#    97/152  STMTREV+F      0h:00:13   0h:13:13         -339223.7886       -       -
#    98/152  DAYHOFF+F      0h:00:11   0h:13:17         -334977.8702       -       -
#    92/152  MTREV+G4       0h:01:26   0h:13:18         -350432.7838  1.2127       -
#    79/152  STMTREV+G4     0h:02:33   0h:13:20         -342815.7571  1.0943       -
#    99/152  FLU+F          0h:00:11   0h:13:23         -337959.4873       -       -
#   100/152  JTT-DCMUT+F    0h:00:11   0h:13:24         -332093.3942       -       -
#   102/152  HIVB+F         0h:00:13   0h:13:31         -339976.9933       -       -
#   101/152  HIVW+F         0h:00:14   0h:13:31         -343776.1194       -       -
#   103/152  PMB+F          0h:00:12   0h:13:32         -330537.5703       -       -
#    80/152  CPREV+G4       0h:02:44   0h:13:32         -331665.2485  1.0884       -
#   105/152  MTART+F        0h:00:10   0h:13:34         -343909.3114       -       -
#   104/152  MTZOA+F        0h:00:11   0h:13:34         -338734.3755       -       -
#    84/152  JTT-DCMUT+G4   0h:02:41   0h:13:35         -330256.2840  1.1372       -
#   106/152  MTMAM+F        0h:00:08   0h:13:39         -347565.8881       -       -
#   107/152  BLOSUM62+F     0h:00:12   0h:13:43         -330818.1587       -       -
#   108/152  VT+F           0h:00:11   0h:13:43         -329951.6813       -       -
#   110/152  RTREV+F        0h:00:11   0h:13:45         -333334.4762       -       -
#   109/152  CPREV+F        0h:00:13   0h:13:45         -332833.3397       -       -
#   111/152  WAG+F          0h:00:12   0h:13:46         -331301.7363       -       -
#   112/152  MTREV+F        0h:00:13   0h:13:48         -337136.0553       -       -
#    88/152  HIVB+G4        0h:02:23   0h:13:51         -338604.5125  1.0000       -
#   113/152  JTT+F          0h:00:13   0h:13:52         -332074.0671       -       -
#   115/152  LG+F           0h:00:11   0h:13:54         -332914.5146       -       -
#   114/152  DCMUT+F        0h:00:11   0h:13:54         -334955.8504       -       -
#   123/152  MTZOA+I        0h:00:12   0h:14:06         -353406.7420       -  0.0792
#   116/152  LG+I           0h:00:23   0h:14:08         -333239.1698       -  0.0763
#   117/152  STMTREV+I      0h:00:23   0h:14:08         -345739.4591       -  0.0893
#   118/152  FLU+I          0h:00:22   0h:14:08         -339115.0636       -  0.0809
#   119/152  JTT-DCMUT+I    0h:00:24   0h:14:12         -332799.6167       -  0.0762
#   120/152  HIVW+I         0h:00:23   0h:14:14         -348332.8363       -  0.0908
#   124/152  MTART+I        0h:00:11   0h:14:17         -360742.5801       -  0.0881
#   121/152  HIVB+I         0h:00:26   0h:14:18         -342067.2316       -  0.0888
#   125/152  MTMAM+I        0h:00:11   0h:14:19         -364540.3604       -  0.0924
#   122/152  PMB+I          0h:00:25   0h:14:19         -332098.7534       -  0.0678
#   126/152  BLOSUM62+I     0h:00:23   0h:14:31         -331630.4887       -  0.0691
#   127/152  VT+I           0h:00:25   0h:14:33         -330638.8011       -  0.0708
#   133/152  MTREV+I        0h:00:15   0h:14:34         -352656.5624       -  0.0776
#    94/152  DCMUT+G4       0h:02:32   0h:14:34         -333810.4371  1.0218       -
#   128/152  CPREV+I        0h:00:23   0h:14:35         -334417.8889       -  0.0739
#    81/152  VT+G4          0h:03:45   0h:14:35         -327984.5793  1.0827       -
#   129/152  RTREV+I        0h:00:22   0h:14:36         -336381.4125       -  0.0739
#   130/152  DAYHOFF+I      0h:00:22   0h:14:39         -336890.3735       -  0.0768
#   132/152  DCMUT+I        0h:00:22   0h:14:41         -336870.0101       -  0.0768
#   131/152  WAG+I          0h:00:23   0h:14:41         -331916.1315       -  0.0710
#   137/152  LG             0h:00:11   0h:14:45         -334171.8729       -       -
#   135/152  JTT-DCMUT      0h:00:12   0h:14:45         -333666.0401       -       -
#   136/152  DAYHOFF        0h:00:13   0h:14:47         -337926.0230       -       -
#   139/152  STMTREV        0h:00:12   0h:14:47         -346932.6521       -       -
#   138/152  DCMUT          0h:00:12   0h:14:47         -337904.1170       -       -
#   140/152  JTT            0h:00:12   0h:14:48         -333680.9845       -       -
#    83/152  BLOSUM62+G4    0h:03:56   0h:14:49         -328886.2988  1.0000       -
#   141/152  MTREV          0h:00:11   0h:14:50         -353869.6146       -       -
#   143/152  WAG            0h:00:12   0h:14:53         -332635.0689       -       -
#   142/152  FLU            0h:00:12   0h:14:53         -340266.4117       -       -
#    93/152  JTT+G4         0h:02:59   0h:14:55         -330274.4640  1.1388       -
#   150/152  MTMAM          0h:00:07   0h:14:56         -365985.4457       -       -
#   144/152  RTREV          0h:00:11   0h:14:56         -337282.0898       -       -
#   134/152  JTT+I          0h:00:26   0h:14:57         -332809.1044       -  0.0765
#   145/152  PMB            0h:00:12   0h:14:57         -332607.9875       -       -
#   147/152  VT             0h:00:11   0h:14:58         -331244.7173       -       -
#   146/152  CPREV          0h:00:11   0h:14:58         -335307.5917       -       -
#   148/152  HIVW           0h:00:12   0h:14:59         -350029.7748       -       -
#   149/152  BLOSUM62       0h:00:11   0h:14:59         -332203.0443       -       -
#   152/152  MTART          0h:00:06   0h:14:59         -362057.0843       -       -
#   153/152  MTZOA          0h:00:06   0h:14:59         -354528.2277       -       -
#   151/152  HIVB           0h:00:10   0h:15:00         -343359.6115       -       -
#    91/152  WAG+G4         0h:03:24   0h:15:01         -329189.0686  1.0900       -
#    95/152  LG+G4          0h:02:42   0h:15:01         -330737.7830  1.1244       -
#    90/152  PMB+G4         0h:03:29   0h:15:02         -329328.3274  1.0000       -
#    96/152  RTREV+G4       0h:02:25   0h:15:06         -333585.5336  1.0963       -
#  ----ID---  ----MODEL---- ---Time--- -Elapsed--- -------LnL------- -Alpha- -P-inv-
#
# Computation of likelihood scores completed. It took 0h:15:06
#
# BIC       model              K            lnL          score          delta    weight
# --------------------------------------------------------------------------------
#        1  VT+G4+F           20   -326719.7971    653965.3506         0.0000    1.0000
#        2  VT+I+G4+F         21   -326801.9876    654140.4613       175.1107    0.0000
#        3  PMB+G4+F          20   -327274.0396    655073.8356      1108.4849    0.0000
#        4  PMB+I+G4+F        21   -327361.1187    655258.7235      1293.3728    0.0000
#        5  BLOSUM62+G4+F     20   -327536.2577    655598.2717      1632.9211    0.0000
#        6  BLOSUM62+I+G4+F   21   -327621.2108    655778.9077      1813.5571    0.0000
#        7  VT+G4              1   -327984.5793    656291.0502      2325.6996    0.0000
#        8  WAG+G4+F          20   -327944.5585    656414.8734      2449.5228    0.0000
#        9  VT+I+G4            2   -328066.7675    656466.1565      2500.8058    0.0000
#       10  WAG+I+G4+F        21   -328020.1628    656576.8118      2611.4611    0.0000
# --------------------------------------------------------------------------------
# Best model according to BIC
# ---------------------------
# Model:              VT+G4+F
# lnL:                -326719.7971
# Frequencies:        0.0699 0.0415 0.0533 0.0621 0.0137 0.0344 0.0681 0.0643 0.0200 0.0608 0.0790 0.0801 0.0287 0.0421 0.0295 0.0646 0.0621 0.0117 0.0435 0.0705
# Inv. sites prop:    -
# Gamma shape:        1.0977
# Score:              653965.3506
# Weight:             1.0000
# ---------------------------
# Parameter importances
# ---------------------------
# P.Inv:              -
# Gamma:              1.0000
# Gamma-Inv:          0.0000
# Frequencies:        1.0000
# ---------------------------
# Model averaged estimates
# ---------------------------
# P.Inv:              -
# Alpha:              1.0977
# Alpha-P.Inv:        1.1519
# P.Inv-Alpha:        0.0216
# Frequencies:        0.0699 0.0415 0.0533 0.0621 0.0137 0.0344 0.0681 0.0643 0.0200 0.0608 0.0790 0.0801 0.0287 0.0421 0.0295 0.0646 0.0621 0.0117 0.0435 0.0705
#
# Commands:
#   > phyml  -i data/aa_seqs_omega_aln.fasta -d aa -m VT -f e -v 0 -a e -c 4 -o tlr
#   > raxmlHPC-SSE3 -s data/aa_seqs_omega_aln.fasta -m PROTGAMMAVTF -n EXEC_NAME -p PARSIMONY_SEED
#   > raxml-ng --msa data/aa_seqs_omega_aln.fasta --model VT+G4+F
#   > paup -s data/aa_seqs_omega_aln.fasta
#   > iqtree -s data/aa_seqs_omega_aln.fasta -m VT+G4+F
#
# AIC       model              K            lnL          score          delta    weight
# --------------------------------------------------------------------------------
#        1  VT+G4+F           20   -326719.7971    653537.5942         0.0000    1.0000
#        2  VT+I+G4+F         21   -326801.9876    653703.9752       166.3809    0.0000
#        3  PMB+G4+F          20   -327274.0396    654646.0792      1108.4849    0.0000
#        4  PMB+I+G4+F        21   -327361.1187    654822.2373      1284.6431    0.0000
#        5  BLOSUM62+G4+F     20   -327536.2577    655170.5153      1632.9211    0.0000
#        6  BLOSUM62+I+G4+F   21   -327621.2108    655342.4216      1804.8274    0.0000
#        7  WAG+G4+F          20   -327944.5585    655987.1170      2449.5228    0.0000
#        8  VT+G4              1   -327984.5793    656029.1586      2491.5643    0.0000
#        9  WAG+I+G4+F        21   -328020.1628    656140.3256      2602.7314    0.0000
#       10  VT+I+G4            2   -328066.7675    656195.5351      2657.9408    0.0000
# --------------------------------------------------------------------------------
# Best model according to AIC
# ---------------------------
# Model:              VT+G4+F
# lnL:                -326719.7971
# Frequencies:        0.0699 0.0415 0.0533 0.0621 0.0137 0.0344 0.0681 0.0643 0.0200 0.0608 0.0790 0.0801 0.0287 0.0421 0.0295 0.0646 0.0621 0.0117 0.0435 0.0705
# Inv. sites prop:    -
# Gamma shape:        1.0977
# Score:              653537.5942
# Weight:             1.0000
# ---------------------------
# Parameter importances
# ---------------------------
# P.Inv:              -
# Gamma:              1.0000
# Gamma-Inv:          0.0000
# Frequencies:        1.0000
# ---------------------------
# Model averaged estimates
# ---------------------------
# P.Inv:              -
# Alpha:              1.0977
# Alpha-P.Inv:        1.1519
# P.Inv-Alpha:        0.0216
# Frequencies:        0.0699 0.0415 0.0533 0.0621 0.0137 0.0344 0.0681 0.0643 0.0200 0.0608 0.0790 0.0801 0.0287 0.0421 0.0295 0.0646 0.0621 0.0117 0.0435 0.0705
#
# Commands:
#   > phyml  -i data/aa_seqs_omega_aln.fasta -d aa -m VT -f e -v 0 -a e -c 4 -o tlr
#   > raxmlHPC-SSE3 -s data/aa_seqs_omega_aln.fasta -m PROTGAMMAVTF -n EXEC_NAME -p PARSIMONY_SEED
#   > raxml-ng --msa data/aa_seqs_omega_aln.fasta --model VT+G4+F
#   > paup -s data/aa_seqs_omega_aln.fasta
#   > iqtree -s data/aa_seqs_omega_aln.fasta -m VT+G4+F
#
# AICc      model              K            lnL          score          delta    weight
# --------------------------------------------------------------------------------
#        1  VT+G4+F           20   -326719.7971    653537.5942         0.0000    1.0000
#        2  VT+I+G4+F         21   -326801.9876    653703.9752       166.3809    0.0000
#        3  PMB+G4+F          20   -327274.0396    654646.0792      1108.4849    0.0000
#        4  PMB+I+G4+F        21   -327361.1187    654822.2373      1284.6431    0.0000
#        5  BLOSUM62+G4+F     20   -327536.2577    655170.5153      1632.9211    0.0000
#        6  BLOSUM62+I+G4+F   21   -327621.2108    655342.4216      1804.8274    0.0000
#        7  WAG+G4+F          20   -327944.5585    655987.1170      2449.5228    0.0000
#        8  VT+G4              1   -327984.5793    656029.1586      2491.5643    0.0000
#        9  WAG+I+G4+F        21   -328020.1628    656140.3256      2602.7314    0.0000
#       10  VT+I+G4            2   -328066.7675    656195.5351      2657.9408    0.0000
# --------------------------------------------------------------------------------
# Best model according to AICc
# ---------------------------
# Model:              VT+G4+F
# lnL:                -326719.7971
# Frequencies:        0.0699 0.0415 0.0533 0.0621 0.0137 0.0344 0.0681 0.0643 0.0200 0.0608 0.0790 0.0801 0.0287 0.0421 0.0295 0.0646 0.0621 0.0117 0.0435 0.0705
# Inv. sites prop:    -
# Gamma shape:        1.0977
# Score:              653537.5942
# Weight:             1.0000
# ---------------------------
# Parameter importances
# ---------------------------
# P.Inv:              -
# Gamma:              1.0000
# Gamma-Inv:          0.0000
# Frequencies:        1.0000
# ---------------------------
# Model averaged estimates
# ---------------------------
# P.Inv:              -
# Alpha:              1.0977
# Alpha-P.Inv:        1.1519
# P.Inv-Alpha:        0.0216
# Frequencies:        0.0699 0.0415 0.0533 0.0621 0.0137 0.0344 0.0681 0.0643 0.0200 0.0608 0.0790 0.0801 0.0287 0.0421 0.0295 0.0646 0.0621 0.0117 0.0435 0.0705
#
# Commands:
#   > phyml  -i data/aa_seqs_omega_aln.fasta -d aa -m VT -f e -v 0 -a e -c 4 -o tlr
#   > raxmlHPC-SSE3 -s data/aa_seqs_omega_aln.fasta -m PROTGAMMAVTF -n EXEC_NAME -p PARSIMONY_SEED
#   > raxml-ng --msa data/aa_seqs_omega_aln.fasta --model VT+G4+F
#   > paup -s data/aa_seqs_omega_aln.fasta
#   > iqtree -s data/aa_seqs_omega_aln.fasta -m VT+G4+F
# Summary:
#
# Partition 1/1:
#                          Model         Score        Weight
# ----------------------------------------------------------
#        BIC             VT+G4+F   653965.3506        1.0000
#        AIC             VT+G4+F   653537.5942        1.0000
#       AICc             VT+G4+F   653537.5942        1.0000
#
# Execution results written to data/aa_seqs_omega_aln.fasta.out
# Starting tree written to data/aa_seqs_omega_aln.fasta.tree

# %%
# !./bin/raxml-ng --help
# Out:
# RAxML-NG v. 1.2.2-master released on 30.04.2024 by The Exelixis Lab.
# Developed by: Alexey M. Kozlov and Alexandros Stamatakis.
# Contributors: Diego Darriba, Tomas Flouri, Benoit Morel, Sarah Lutteropp, Ben Bettisworth, Julia Haag, Anastasis Togkousidis.
# Latest version: https://github.com/amkozlov/raxml-ng
# Questions/problems/suggestions? Please visit: https://groups.google.com/forum/#!forum/raxml
#
# System: AMD Ryzen 7 5800H with Radeon Graphics, 8 cores, 14 GB RAM
#
# Usage: raxml-ng [OPTIONS]
#
# Commands (mutually exclusive):
#   --help                                     display help information
#   --version                                  display version information
#   --evaluate                                 evaluate the likelihood of a tree (with model+brlen optimization)
#   --search                                   ML tree search (default: 10 parsimony + 10 random starting trees)
#   --bootstrap                                bootstrapping (default: use bootstopping to auto-detect #replicates)
#   --all                                      all-in-one (ML search + bootstrapping)
#   --support                                  compute bipartition support for a given reference tree (e.g., best ML tree)
#                                              and a set of replicate trees (e.g., from a bootstrap analysis)
#   --bsconverge                               test for bootstrapping convergence using autoMRE criterion
#   --bsmsa                                    generate bootstrap replicate MSAs
#   --terrace                                  check whether a tree lies on a phylogenetic terrace
#   --check                                    check alignment correctness and remove empty columns/rows
#   --parse                                    parse alignment, compress patterns and create binary MSA file
#   --start                                    generate parsimony/random starting trees and exit
#   --rfdist                                   compute pair-wise Robinson-Foulds (RF) distances between trees
#   --consense [ STRICT | MR | MR<n> | MRE ]   build strict, majority-rule (MR) or extended MR (MRE) consensus tree (default: MR)
#                                              eg: --consense MR75 --tree bsrep.nw
#   --ancestral                                ancestral state reconstruction at all inner nodes
#   --sitelh                                   print per-site log-likelihood values
#
# Command shortcuts (mutually exclusive):
#   --search1                                  Alias for: --search --tree rand{1}
#   --loglh                                    Alias for: --evaluate --opt-model off --opt-branches off --nofiles --log result
#   --rf                                       Alias for: --rfdist --nofiles --log result
#
# Input and output options:
#   --tree            rand{N} | pars{N} | FILE starting tree: rand(om), pars(imony) or user-specified (newick file)
#                                              N = number of trees (default: rand{10},pars{10})
#   --msa             FILE                     alignment file
#   --msa-format      VALUE                    alignment file format: FASTA, PHYLIP, CATG or AUTO-detect (default)
#   --data-type       VALUE                    data type: DNA, AA, BIN(ary) or AUTO-detect (default)
#   --tree-constraint FILE                     constraint tree
#   --prefix          STRING                   prefix for output files (default: MSA file name)
#   --log             VALUE                    log verbosity: ERROR,WARNING,RESULT,INFO,PROGRESS,DEBUG (default: PROGRESS)
#   --redo                                     overwrite existing result files and ignore checkpoints (default: OFF)
#   --nofiles                                  do not create any output files, print results to the terminal only
#   --precision       VALUE                    number of decimal places to print (default: 6)
#   --outgroup        o1,o2,..,oN              comma-separated list of outgroup taxon names (it's just a drawing option!)
#   --site-weights    FILE                     file with MSA column weights (positive integers only!)
#
# General options:
#   --seed         VALUE                       seed for pseudo-random number generator (default: current time)
#   --pat-comp     on | off                    alignment pattern compression (default: ON)
#   --tip-inner    on | off                    tip-inner case optimization (default: OFF)
#   --site-repeats on | off                    use site repeats optimization, 10%-60% faster than tip-inner (default: ON)
#   --threads      VALUE                       number of parallel threads to use (default: 8)
#   --workers      VALUE                       number of tree searches to run in parallel (default: 1)
#   --simd         none | sse3 | avx | avx2    vector instruction set to use (default: auto-detect).
#   --rate-scalers on | off                    use individual CLV scalers for each rate category (default: ON for >2000 taxa)
#   --force        [ <CHECKS> ]                disable safety checks (please think twice!)
#
# Model options:
#   --model        <name>+G[n]+<Freqs> | FILE  model specification OR partition file
#   --brlen        linked | scaled | unlinked  branch length linkage between partitions (default: scaled)
#   --blmin        VALUE                       minimum branch length (default: 1e-6)
#   --blmax        VALUE                       maximum branch length (default: 100)
#   --blopt        nr_fast    | nr_safe        branch length optimization method (default: nr_fast)
#                  nr_oldfast | nr_oldsafe
#   --opt-model    on | off                    ML optimization of all model parameters (default: ON)
#   --opt-branches on | off                    ML optimization of all branch lengths (default: ON)
#   --prob-msa     on | off                    use probabilistic alignment (works with CATG and VCF)
#   --lh-epsilon   VALUE                       log-likelihood epsilon for optimization/tree search (default: 0.1)
#
# Topology search options:
#   --spr-radius           VALUE               SPR re-insertion radius for fast iterations (default: AUTO)
#   --spr-cutoff           VALUE | off         relative LH cutoff for descending into subtrees (default: 1.0)
#   --lh-epsilon-triplet   VALUE               log-likelihood epsilon for branch length triplet optimization (default: 1000)
#
# Bootstrapping options:
#   --bs-trees     VALUE                       number of bootstraps replicates
#   --bs-trees     autoMRE{N}                  use MRE-based bootstrap convergence criterion, up to N replicates (default: 1000)
#   --bs-trees     FILE                        Newick file containing set of bootstrap replicate trees (with --support)
#   --bs-cutoff    VALUE                       cutoff threshold for the MRE-based bootstopping criteria (default: 0.03)
#   --bs-metric    fbp | tbe                   branch support metric: fbp = Felsenstein bootstrap (default), tbe = transfer distance
#   --bs-write-msa on | off                    write all bootstrap alignments (default: OFF)
#
# EXAMPLES:
#   1. Perform tree inference on DNA alignment
#      (10 random + 10 parsimony starting trees, general time-reversible model, ML estimate of substitution rates and
#       nucleotide frequencies, discrete GAMMA model of rate heterogeneity with 4 categories):
#
#      ./raxml-ng --msa testDNA.fa --model GTR+G
#
#
#   2. Perform an all-in-one analysis (ML tree search + non-parametric bootstrap)
#      (10 randomized parsimony starting trees, fixed empirical substitution matrix (LG),
#       empirical aminoacid frequencies from alignment, 8 discrete GAMMA categories,
#       200 bootstrap replicates):
#
#      ./raxml-ng --all --msa testAA.fa --model LG+G8+F --tree pars{10} --bs-trees 200
#
#
#   3. Optimize branch lengths and free model parameters on a fixed topology
#      (using multiple partitions with proportional branch lengths)
#
#      ./raxml-ng --evaluate --msa testAA.fa --model partitions.txt --tree test.tree --brlen scaled

# %%
# !./bin/raxml-ng --msa 'data/aa_seqs_omega_aln.fasta' --model VT+G4+F --prefix T1 --threads 30 --log debug
# Out:
# RAxML-NG v. 1.2.2-master released on 30.04.2024 by The Exelixis Lab.
# Developed by: Alexey M. Kozlov and Alexandros Stamatakis.
# Contributors: Diego Darriba, Tomas Flouri, Benoit Morel, Sarah Lutteropp, Ben Bettisworth, Julia Haag, Anastasis Togkousidis.
# Latest version: https://github.com/amkozlov/raxml-ng
# Questions/problems/suggestions? Please visit: https://groups.google.com/forum/#!forum/raxml
#
# System: AMD Ryzen 7 5800H with Radeon Graphics, 8 cores, 14 GB RAM
#
# RAxML-NG was called at 09-May-2024 12:03:52 as follows:
#
# ./bin/raxml-ng --msa data/aa_seqs_omega_aln.fasta --model LG+G4 --prefix T1 --threads 14 --log debug
#
# Analysis options:
#   run mode: ML tree search
#   start tree(s): random (10) + parsimony (10)
#   random seed: 1715231032
#   tip-inner: OFF
#   pattern compression: ON
#   per-rate scalers: OFF
#   site repeats: ON
#   logLH epsilon: general: 10.000000, brlen-triplet: 1000.000000
#   fast spr radius: AUTO
#   spr subtree cutoff: 1.000000
#   fast CLV updates: ON
#   branch lengths: proportional (ML estimate, algorithm: NR-FAST)
#   SIMD kernels: AVX2
#   parallelization: coarse-grained (auto), PTHREADS (14 threads), thread pinning: OFF
#
# RBA partial loading: OFF
# |noname|   |LG+G4m|   ||
# [00:00:00] Reading alignment from file: data/aa_seqs_omega_aln.fasta
# Failed to load as IPHYLIP: Unable to parse PHYLIP file: data/aa_seqs_omega_aln.fasta
#  (LIBPLL-231): Invalid number of sequences in header
# Failed to load as PHYLIP: Unable to parse PHYLIP file: data/aa_seqs_omega_aln.fasta
#  (LIBPLL-231): Invalid number of sequences in header
# [00:00:00] Loaded alignment with 16 taxa and 45694 sites
# [00:00:00] Extracting partitions...
# [00:00:00] Checking the alignment...
# [00:00:00] Compressing alignment patterns...
#
# Alignment comprises 1 partitions and 16193 patterns
#
# Partition 0: noname
# Model: LG+G4m
# Alignment sites / patterns: 45694 / 16193
# Gaps: 43.84 %
# Invariant sites: 43.59 %
#
#
# NOTE: Binary MSA file created: T1.raxml.rba
#
# Recommended threads (response/balanced/throughput): 51 / 19 / 8
#
# Parallelization scheme autoconfig: 1 worker(s) x 14 thread(s)
#
# [00:00:00] Generating a RANDOM starting tree, seed: 1059922069
# [00:00:00] Generating 10 random starting tree(s) with 16 taxa
# [00:00:00] Generating a RANDOM starting tree, seed: 1815033889
# [00:00:00] Generating a RANDOM starting tree, seed: 668302956
# [00:00:00] Generating a RANDOM starting tree, seed: 548419336
# [00:00:00] Generating a RANDOM starting tree, seed: 378552736
# [00:00:00] Generating a RANDOM starting tree, seed: 1867771877
# [00:00:00] Generating a RANDOM starting tree, seed: 1851059108
# [00:00:00] Generating a RANDOM starting tree, seed: 121168951
# [00:00:00] Generating a RANDOM starting tree, seed: 856106213
# [00:00:00] Generating a RANDOM starting tree, seed: 1935218559
# [00:00:00] Generating a RANDOM starting tree, seed: 496321384
# [00:00:00] Generating 10 parsimony starting tree(s) with 16 taxa
# Estimated memory per parsimony thread: 2 MB
# Parallel parsimony with 14 threads
# [00:00:00] [worker #6] Generated a PARSIMONY starting tree, seed: 1113893366, score: 48348
# [00:00:00] [worker #3] Generated a PARSIMONY starting tree, seed: 302396732, score: 48265
# [00:00:00] [worker #4] Generated a PARSIMONY starting tree, seed: 573576475, score: 48416
# [00:00:00] [worker #7] Generated a PARSIMONY starting tree, seed: 1587333859, score: 48215
# [00:00:00] [worker #8] Generated a PARSIMONY starting tree, seed: 1516535688, score: 48343
# [00:00:00] [worker #5] Generated a PARSIMONY starting tree, seed: 39684220, score: 48319
# [00:00:00] [worker #1] Generated a PARSIMONY starting tree, seed: 245701538, score: 48221
# [00:00:00] [worker #0] Generated a PARSIMONY starting tree, seed: 1794618716, score: 48316
# [00:00:00] [worker #2] Generated a PARSIMONY starting tree, seed: 507244516, score: 48255
# [00:00:00] [worker #9] Generated a PARSIMONY starting tree, seed: 1416736033, score: 48322
# Parallel reduction/worker buffer size: 1 KB  / 0 KB
#
#
# Initial model parameters:
#    Partition: noname
#    Rate heterogeneity: GAMMA (4 cats, mean),  alpha: 1.000000 (ML),  weights&rates: (0.250000,0.136954) (0.250000,0.476752) (0.250000,1.000000) (0.250000,2.386294)
#    Base frequencies (model): 0.079066 0.055941 0.041977 0.053052 0.012937 0.040767 0.071586 0.057337 0.022355 0.062157 0.099081 0.064600 0.022951 0.042302 0.044040 0.061197 0.053287 0.012066 0.034155 0.069147
#    Substitution rates (model): 0.425093 0.276818 0.395144 2.489084 0.969894 1.038545 2.066040 0.358858 0.149830 0.395337 0.536518 1.124035 0.253701 1.177651 4.727182 2.139501 0.180717 0.218959 2.547870 0.751878 0.123954 0.534551 2.807908 0.363970 0.390192 2.426601 0.126991 0.301848 6.326067 0.484133 0.052722 0.332533 0.858151 0.578987 0.593607 0.314440 0.170887 5.076149 0.528768 1.695752 0.541712 1.437645 4.509238 0.191503 0.068427 2.145078 0.371004 0.089525 0.161787 4.008358 2.000679 0.045376 0.612025 0.083688 0.062556 0.523386 5.243870 0.844926 0.927114 0.010690 0.015076 0.282959 0.025548 0.017416 0.394456 1.240275 0.425860 0.029890 0.135107 0.037967 0.084808 0.003499 0.569265 0.640543 0.320627 0.594007 0.013266 0.893680 1.105251 0.075382 2.784478 1.143480 0.670128 1.165532 1.959291 4.128591 0.267959 4.813505 0.072854 0.582457 3.234294 1.672569 0.035855 0.624294 1.223828 1.080136 0.236199 0.257336 0.210332 0.348847 0.423881 0.044265 0.069673 1.807177 0.173735 0.018811 0.419409 0.611973 0.604545 0.077852 0.120037 0.245034 0.311484 0.008705 0.044261 0.296636 0.139538 0.089586 0.196961 1.739990 0.129836 0.268491 0.054679 0.076701 0.108882 0.366317 0.697264 0.442472 0.682139 0.508851 0.990012 0.584262 0.597054 5.306834 0.119013 4.145067 0.159069 4.273607 1.112727 0.078281 0.064105 1.033739 0.111660 0.232523 10.649107 0.137500 6.312358 2.592692 0.249060 0.182287 0.302936 0.619632 0.299648 1.702745 0.656604 0.023918 0.390322 0.748683 1.136863 0.049906 0.131932 0.185202 1.798853 0.099849 0.346960 2.020366 0.696175 0.481306 1.898718 0.094464 0.361819 0.165001 2.457121 7.803902 0.654683 1.338132 0.571468 0.095131 0.089613 0.296501 6.472279 0.248862 0.400547 0.098369 0.140825 0.245841 2.188158 3.151815 0.189510 0.249313
#
# [00:00:00] Data distribution: max. partitions/sites/weight per thread: 1 / 1157 / 92560
#
# thread#	part#	start	length	weight
# 0	0	15041	1152	92160
#
# 1	0	13884	1157	92560
#
# 2	0	12727	1157	92560
#
# 3	0	11570	1157	92560
#
# 4	0	10413	1157	92560
#
# 5	0	9256	1157	92560
#
# 6	0	8099	1157	92560
#
# 7	0	6942	1157	92560
#
# 8	0	5785	1157	92560
#
# 9	0	4628	1157	92560
#
# 10	0	3471	1157	92560
#
# 11	0	2314	1157	92560
#
# 12	0	1157	1157	92560
#
# 13	0	0	1157	92560
#
# [00:00:00] Data distribution: max. searches per worker: 20
#
# BARRIER time: 0.003101 ms
#
# Starting ML tree search with 20 distinct starting trees
#
# [00:00:00 -771101.004300] Initial branch length optimization
# 	 - after brlen: logLH = -578230.065314
# [00:00:00 -578230.065314] Model parameter optimization (eps = 10.000000)
# 	 - after rates: logLH = -578230.065314
# 	 - after freqs: logLH = -578230.065314
# 	 - after alpha: logLH = -568167.420989
# 	 - after p-inv: logLH = -568167.420989
# 	 - after freeR: logLH = -568167.420989
# 	 - after brlen: logLH = -564537.242607
# Iteration 1: logLH = -564537.242607
# 	 - after rates: logLH = -564537.242607
# 	 - after freqs: logLH = -564537.242607
# 	 - after alpha: logLH = -564522.114594
# 	 - after p-inv: logLH = -564522.114594
# 	 - after freeR: logLH = -564522.114594
# 	 - after brlen: logLH = -563900.236998
# Iteration 2: logLH = -563900.236998
# 	 - after rates: logLH = -563900.236998
# 	 - after freqs: logLH = -563900.236998
# 	 - after alpha: logLH = -563633.437247
# 	 - after p-inv: logLH = -563633.437247
# 	 - after freeR: logLH = -563633.437247
# 	 - after brlen: logLH = -563381.275591
# Iteration 3: logLH = -563381.275591
# 	 - after rates: logLH = -563381.275591
# 	 - after freqs: logLH = -563381.275591
# 	 - after alpha: logLH = -563233.972490
# 	 - after p-inv: logLH = -563233.972490
# 	 - after freeR: logLH = -563233.972490
# 	 - after brlen: logLH = -563094.926631
# Iteration 4: logLH = -563094.926631
# 	 - after rates: logLH = -563094.926631
# 	 - after freqs: logLH = -563094.926631
# 	 - after alpha: logLH = -563017.261825
# 	 - after p-inv: logLH = -563017.261825
# 	 - after freeR: logLH = -563017.261825
# 	 - after brlen: logLH = -562934.051319
# Iteration 5: logLH = -562934.051319
# 	 - after rates: logLH = -562934.051319
# 	 - after freqs: logLH = -562934.051319
# 	 - after alpha: logLH = -562886.400113
# 	 - after p-inv: logLH = -562886.400113
# 	 - after freeR: logLH = -562886.400113
# 	 - after brlen: logLH = -562836.327345
# Iteration 6: logLH = -562836.327345
# 	 - after rates: logLH = -562836.327345
# 	 - after freqs: logLH = -562836.327345
# 	 - after alpha: logLH = -562806.774198
# 	 - after p-inv: logLH = -562806.774198
# 	 - after freeR: logLH = -562806.774198
# 	 - after brlen: logLH = -562777.225469
# Iteration 7: logLH = -562777.225469
# 	 - after rates: logLH = -562777.225469
# 	 - after freqs: logLH = -562777.225469
# 	 - after alpha: logLH = -562763.161531
# 	 - after p-inv: logLH = -562763.161531
# 	 - after freeR: logLH = -562763.161531
# 	 - after brlen: logLH = -562743.516477
# Iteration 8: logLH = -562743.516477
# 	 - after rates: logLH = -562743.516477
# 	 - after freqs: logLH = -562743.516477
# 	 - after alpha: logLH = -562733.730703
# 	 - after p-inv: logLH = -562733.730703
# 	 - after freeR: logLH = -562733.730703
# 	 - after brlen: logLH = -562719.934680
# Iteration 9: logLH = -562719.934680
# 	 - after rates: logLH = -562719.934680
# 	 - after freqs: logLH = -562719.934680
# 	 - after alpha: logLH = -562713.245808
# 	 - after p-inv: logLH = -562713.245808
# 	 - after freeR: logLH = -562713.245808
# 	 - after brlen: logLH = -562706.102031
# Iteration 10: logLH = -562706.102031
# 	 - after rates: logLH = -562706.102031
# 	 - after freqs: logLH = -562706.102031
# 	 - after alpha: logLH = -562703.809878
# 	 - after p-inv: logLH = -562703.809878
# 	 - after freeR: logLH = -562703.809878
# 	 - after brlen: logLH = -562697.629238
# Iteration 11: logLH = -562697.629238
# [00:00:10 -562697.629238] AUTODETECT spr round 1 (radius: 5)
# [00:00:14 -402406.162515] AUTODETECT spr round 2 (radius: 10)
# [00:00:17 -400698.579777] AUTODETECT spr round 3 (radius: 15)
# [00:00:17 -385641.399788] SPR radius for FAST iterations: 15 (autodetect)
# [00:00:17 -385641.399788] Model parameter optimization (eps = 3.000000)
# 	 - after rates: logLH = -385641.399788
# 	 - after freqs: logLH = -385641.399788
# 	 - after alpha: logLH = -383115.626467
# 	 - after p-inv: logLH = -383115.626467
# 	 - after freeR: logLH = -383115.626467
# 	 - after brlen: logLH = -383013.596036
# Iteration 1: logLH = -383013.596036
# 	 - after rates: logLH = -383013.596036
# 	 - after freqs: logLH = -383013.596036
# 	 - after alpha: logLH = -383012.394180
# 	 - after p-inv: logLH = -383012.394180
# 	 - after freeR: logLH = -383012.394180
# 	 - after brlen: logLH = -383012.360440
# Iteration 2: logLH = -383012.360440
# [00:00:20 -383012.360440] FAST spr round 1 (radius: 15)
# 	 - after brlen: logLH = -355876.971349
# [00:00:30 -355876.971349] FAST spr round 2 (radius: 15)
# 	 - after brlen: logLH = -329078.350697
# [00:00:40 -329078.350697] FAST spr round 3 (radius: 15)
# 	 - after brlen: logLH = -328985.911468
# [00:00:49 -328985.911468] FAST spr round 4 (radius: 15)
# 	 - after brlen: logLH = -328985.910203
# [00:00:57 -328985.910203] Model parameter optimization (eps = 1.000000)
# 	 - after rates: logLH = -328985.910203
# 	 - after freqs: logLH = -328985.910203
# 	 - after alpha: logLH = -328557.162400
# 	 - after p-inv: logLH = -328557.162400
# 	 - after freeR: logLH = -328557.162400
# 	 - after brlen: logLH = -328546.192476
# Iteration 1: logLH = -328546.192476
# 	 - after rates: logLH = -328546.192476
# 	 - after freqs: logLH = -328546.192476
# 	 - after alpha: logLH = -328546.033328
# 	 - after p-inv: logLH = -328546.033328
# 	 - after freeR: logLH = -328546.033328
# 	 - after brlen: logLH = -328545.996567
# Iteration 2: logLH = -328545.996567
# [00:00:58 -328545.996567] SLOW spr round 1 (radius: 5)
# 	 - after brlen: logLH = -328545.994274
# [00:01:13 -328545.994274] SLOW spr round 2 (radius: 10)
# 	 - after brlen: logLH = -328545.993277
# [00:01:26 -328545.993277] SLOW spr round 3 (radius: 15)
# 	 - after brlen: logLH = -328545.992279
# [00:01:26 -328545.992279] Model parameter optimization (eps = 0.100000)
# 	 - after rates: logLH = -328545.992279
# 	 - after freqs: logLH = -328545.992279
# 	 - after alpha: logLH = -328545.992279
# 	 - after p-inv: logLH = -328545.992279
# 	 - after freeR: logLH = -328545.992279
# 	 - after brlen: logLH = -328545.991781
# Iteration 1: logLH = -328545.991781
#
# [00:01:27] ML tree search #1, logLikelihood: -328545.991781
#
# [00:01:27 -749330.203181] Initial branch length optimization
# 	 - after brlen: logLH = -571249.204059
# [00:01:28 -571249.204059] Model parameter optimization (eps = 10.000000)
# 	 - after rates: logLH = -571249.204059
# 	 - after freqs: logLH = -571249.204059
# 	 - after alpha: logLH = -562614.148319
# 	 - after p-inv: logLH = -562614.148319
# 	 - after freeR: logLH = -562614.148319
# 	 - after brlen: logLH = -558448.286809
# Iteration 1: logLH = -558448.286809
# 	 - after rates: logLH = -558448.286809
# 	 - after freqs: logLH = -558448.286809
# 	 - after alpha: logLH = -558150.453633
# 	 - after p-inv: logLH = -558150.453633
# 	 - after freeR: logLH = -558150.453633
# 	 - after brlen: logLH = -557726.594280
# Iteration 2: logLH = -557726.594280
# 	 - after rates: logLH = -557726.594280
# 	 - after freqs: logLH = -557726.594280
# 	 - after alpha: logLH = -557489.278857
# 	 - after p-inv: logLH = -557489.278857
# 	 - after freeR: logLH = -557489.278857
# 	 - after brlen: logLH = -557253.072348
# Iteration 3: logLH = -557253.072348
# 	 - after rates: logLH = -557253.072348
# 	 - after freqs: logLH = -557253.072348
# 	 - after alpha: logLH = -557103.747362
# 	 - after p-inv: logLH = -557103.747362
# 	 - after freeR: logLH = -557103.747362
# 	 - after brlen: logLH = -556969.374291
# Iteration 4: logLH = -556969.374291
# 	 - after rates: logLH = -556969.374291
# 	 - after freqs: logLH = -556969.374291
# 	 - after alpha: logLH = -556886.979556
# 	 - after p-inv: logLH = -556886.979556
# 	 - after freeR: logLH = -556886.979556
# 	 - after brlen: logLH = -556804.410819
# Iteration 5: logLH = -556804.410819
# 	 - after rates: logLH = -556804.410819
# 	 - after freqs: logLH = -556804.410819
# 	 - after alpha: logLH = -556753.478966
# 	 - after p-inv: logLH = -556753.478966
# 	 - after freeR: logLH = -556753.478966
# 	 - after brlen: logLH = -556704.357394
# Iteration 6: logLH = -556704.357394
# 	 - after rates: logLH = -556704.357394
# 	 - after freqs: logLH = -556704.357394
# 	 - after alpha: logLH = -556678.517136
# 	 - after p-inv: logLH = -556678.517136
# 	 - after freeR: logLH = -556678.517136
# 	 - after brlen: logLH = -556645.768859
# Iteration 7: logLH = -556645.768859
# 	 - after rates: logLH = -556645.768859
# 	 - after freqs: logLH = -556645.768859
# 	 - after alpha: logLH = -556628.342323
# 	 - after p-inv: logLH = -556628.342323
# 	 - after freeR: logLH = -556628.342323
# 	 - after brlen: logLH = -556606.058238
# Iteration 8: logLH = -556606.058238
# 	 - after rates: logLH = -556606.058238
# 	 - after freqs: logLH = -556606.058238
# 	 - after alpha: logLH = -556594.077799
# 	 - after p-inv: logLH = -556594.077799
# 	 - after freeR: logLH = -556594.077799
# 	 - after brlen: logLH = -556578.644528
# Iteration 9: logLH = -556578.644528
# 	 - after rates: logLH = -556578.644528
# 	 - after freqs: logLH = -556578.644528
# 	 - after alpha: logLH = -556570.288255
# 	 - after p-inv: logLH = -556570.288255
# 	 - after freeR: logLH = -556570.288255
# 	 - after brlen: logLH = -556561.589063
# Iteration 10: logLH = -556561.589063
# 	 - after rates: logLH = -556561.589063
# 	 - after freqs: logLH = -556561.589063
# 	 - after alpha: logLH = -556558.422097
# 	 - after p-inv: logLH = -556558.422097
# 	 - after freeR: logLH = -556558.422097
# 	 - after brlen: logLH = -556551.151620
# Iteration 11: logLH = -556551.151620
# 	 - after rates: logLH = -556551.151620
# 	 - after freqs: logLH = -556551.151620
# 	 - after alpha: logLH = -556548.776444
# 	 - after p-inv: logLH = -556548.776444
# 	 - after freeR: logLH = -556548.776444
# 	 - after brlen: logLH = -556542.977498
# Iteration 12: logLH = -556542.977498
# [00:01:38 -556542.977498] AUTODETECT spr round 1 (radius: 5)
# [00:01:42 -330902.795120] AUTODETECT spr round 2 (radius: 10)
# [00:01:43 -330902.570419] AUTODETECT spr round 3 (radius: 15)
# [00:01:44 -330902.563671] SPR radius for FAST iterations: 10 (autodetect)
# [00:01:44 -330902.563671] Model parameter optimization (eps = 3.000000)
# 	 - after rates: logLH = -330902.563671
# 	 - after freqs: logLH = -330902.563671
# 	 - after alpha: logLH = -329563.121240
# 	 - after p-inv: logLH = -329563.121240
# 	 - after freeR: logLH = -329563.121240
# 	 - after brlen: logLH = -329502.821186
# Iteration 1: logLH = -329502.821186
# 	 - after rates: logLH = -329502.821186
# 	 - after freqs: logLH = -329502.821186
# 	 - after alpha: logLH = -329501.837656
# 	 - after p-inv: logLH = -329501.837656
# 	 - after freeR: logLH = -329501.837656
# 	 - after brlen: logLH = -329501.805427
# Iteration 2: logLH = -329501.805427
# [00:01:45 -329501.805427] FAST spr round 1 (radius: 10)
# 	 - after brlen: logLH = -328615.551032
# [00:01:54 -328615.551032] FAST spr round 2 (radius: 10)
# 	 - after brlen: logLH = -328546.441323
# [00:02:01 -328546.441323] FAST spr round 3 (radius: 10)
# 	 - after brlen: logLH = -328545.972584
# [00:02:09 -328545.972584] Model parameter optimization (eps = 1.000000)
# 	 - after rates: logLH = -328545.972584
# 	 - after freqs: logLH = -328545.972584
# 	 - after alpha: logLH = -328545.943328
# 	 - after p-inv: logLH = -328545.943328
# 	 - after freeR: logLH = -328545.943328
# 	 - after brlen: logLH = -328545.941766
# Iteration 1: logLH = -328545.941766
# [00:02:10 -328545.941766] SLOW spr round 1 (radius: 5)
# 	 - after brlen: logLH = -328545.748608
# [00:02:24 -328545.748608] SLOW spr round 2 (radius: 10)
# 	 - after brlen: logLH = -328545.746939
# [00:02:35 -328545.746939] SLOW spr round 3 (radius: 15)
# 	 - after brlen: logLH = -328545.745299
# [00:02:36 -328545.745299] Model parameter optimization (eps = 0.100000)
# 	 - after rates: logLH = -328545.745299
# 	 - after freqs: logLH = -328545.745299
# 	 - after alpha: logLH = -328545.745299
# 	 - after p-inv: logLH = -328545.745299
# 	 - after freeR: logLH = -328545.745299
# 	 - after brlen: logLH = -328545.744480
# Iteration 1: logLH = -328545.744480
#
# [00:02:36] ML tree search #2, logLikelihood: -328545.744480
#
# [00:02:36 -597447.217606] Initial branch length optimization
# 	 - after brlen: logLH = -449642.327619
# [00:02:37 -449642.327619] Model parameter optimization (eps = 10.000000)
# 	 - after rates: logLH = -449642.327619
# 	 - after freqs: logLH = -449642.327619
# 	 - after alpha: logLH = -445839.421947
# 	 - after p-inv: logLH = -445839.421947
# 	 - after freeR: logLH = -445839.421947
# 	 - after brlen: logLH = -443421.372826
# Iteration 1: logLH = -443421.372826
# 	 - after rates: logLH = -443421.372826
# 	 - after freqs: logLH = -443421.372826
# 	 - after alpha: logLH = -442358.767326
# 	 - after p-inv: logLH = -442358.767326
# 	 - after freeR: logLH = -442358.767326
# 	 - after brlen: logLH = -441424.209904
# Iteration 2: logLH = -441424.209904
# 	 - after rates: logLH = -441424.209904
# 	 - after freqs: logLH = -441424.209904
# 	 - after alpha: logLH = -440905.544523
# 	 - after p-inv: logLH = -440905.544523
# 	 - after freeR: logLH = -440905.544523
# 	 - after brlen: logLH = -440449.939152
# Iteration 3: logLH = -440449.939152
# 	 - after rates: logLH = -440449.939152
# 	 - after freqs: logLH = -440449.939152
# 	 - after alpha: logLH = -440183.545263
# 	 - after p-inv: logLH = -440183.545263
# 	 - after freeR: logLH = -440183.545263
# 	 - after brlen: logLH = -439933.680461
# Iteration 4: logLH = -439933.680461
# 	 - after rates: logLH = -439933.680461
# 	 - after freqs: logLH = -439933.680461
# 	 - after alpha: logLH = -439771.927707
# 	 - after p-inv: logLH = -439771.927707
# 	 - after freeR: logLH = -439771.927707
# 	 - after brlen: logLH = -439620.827409
# Iteration 5: logLH = -439620.827409
# 	 - after rates: logLH = -439620.827409
# 	 - after freqs: logLH = -439620.827409
# 	 - after alpha: logLH = -439515.259423
# 	 - after p-inv: logLH = -439515.259423
# 	 - after freeR: logLH = -439515.259423
# 	 - after brlen: logLH = -439414.767597
# Iteration 6: logLH = -439414.767597
# 	 - after rates: logLH = -439414.767597
# 	 - after freqs: logLH = -439414.767597
# 	 - after alpha: logLH = -439342.574586
# 	 - after p-inv: logLH = -439342.574586
# 	 - after freeR: logLH = -439342.574586
# 	 - after brlen: logLH = -439277.010713
# Iteration 7: logLH = -439277.010713
# 	 - after rates: logLH = -439277.010713
# 	 - after freqs: logLH = -439277.010713
# 	 - after alpha: logLH = -439231.826893
# 	 - after p-inv: logLH = -439231.826893
# 	 - after freeR: logLH = -439231.826893
# 	 - after brlen: logLH = -439181.414479
# Iteration 8: logLH = -439181.414479
# 	 - after rates: logLH = -439181.414479
# 	 - after freqs: logLH = -439181.414479
# 	 - after alpha: logLH = -439147.915431
# 	 - after p-inv: logLH = -439147.915431
# 	 - after freeR: logLH = -439147.915431
# 	 - after brlen: logLH = -439110.891281
# Iteration 9: logLH = -439110.891281
# 	 - after rates: logLH = -439110.891281
# 	 - after freqs: logLH = -439110.891281
# 	 - after alpha: logLH = -439085.397960
# 	 - after p-inv: logLH = -439085.397960
# 	 - after freeR: logLH = -439085.397960
# 	 - after brlen: logLH = -439057.936149
# Iteration 10: logLH = -439057.936149
# 	 - after rates: logLH = -439057.936149
# 	 - after freqs: logLH = -439057.936149
# 	 - after alpha: logLH = -439038.184695
# 	 - after p-inv: logLH = -439038.184695
# 	 - after freeR: logLH = -439038.184695
# 	 - after brlen: logLH = -439017.078144
# Iteration 11: logLH = -439017.078144
# 	 - after rates: logLH = -439017.078144
# 	 - after freqs: logLH = -439017.078144
# 	 - after alpha: logLH = -439001.639317
# 	 - after p-inv: logLH = -439001.639317
# 	 - after freeR: logLH = -439001.639317
# 	 - after brlen: logLH = -438984.407593
# Iteration 12: logLH = -438984.407593
# 	 - after rates: logLH = -438984.407593
# 	 - after freqs: logLH = -438984.407593
# 	 - after alpha: logLH = -438972.365168
# 	 - after p-inv: logLH = -438972.365168
# 	 - after freeR: logLH = -438972.365168
# 	 - after brlen: logLH = -438959.463793
# Iteration 13: logLH = -438959.463793
# 	 - after rates: logLH = -438959.463793
# 	 - after freqs: logLH = -438959.463793
# 	 - after alpha: logLH = -438949.829909
# 	 - after p-inv: logLH = -438949.829909
# 	 - after freeR: logLH = -438949.829909
# 	 - after brlen: logLH = -438940.909055
# Iteration 14: logLH = -438940.909055
# 	 - after rates: logLH = -438940.909055
# 	 - after freqs: logLH = -438940.909055
# 	 - after alpha: logLH = -438936.712638
# 	 - after p-inv: logLH = -438936.712638
# 	 - after freeR: logLH = -438936.712638
# 	 - after brlen: logLH = -438928.614992
# Iteration 15: logLH = -438928.614992
# 	 - after rates: logLH = -438928.614992
# 	 - after freqs: logLH = -438928.614992
# 	 - after alpha: logLH = -438924.836681
# 	 - after p-inv: logLH = -438924.836681
# 	 - after freeR: logLH = -438924.836681
# 	 - after brlen: logLH = -438917.963724
# Iteration 16: logLH = -438917.963724
# 	 - after rates: logLH = -438917.963724
# 	 - after freqs: logLH = -438917.963724
# 	 - after alpha: logLH = -438914.763430
# 	 - after p-inv: logLH = -438914.763430
# 	 - after freeR: logLH = -438914.763430
# 	 - after brlen: logLH = -438909.994429
# Iteration 17: logLH = -438909.994429
# [00:02:49 -438909.994429] AUTODETECT spr round 1 (radius: 5)
# [00:02:52 -400858.844037] AUTODETECT spr round 2 (radius: 10)
# [00:02:54 -400857.413947] AUTODETECT spr round 3 (radius: 15)
# [00:02:55 -400856.565229] SPR radius for FAST iterations: 15 (autodetect)
# [00:02:55 -400856.565229] Model parameter optimization (eps = 3.000000)
# 	 - after rates: logLH = -400856.565229
# 	 - after freqs: logLH = -400856.565229
# 	 - after alpha: logLH = -393191.976829
# 	 - after p-inv: logLH = -393191.976829
# 	 - after freeR: logLH = -393191.976829
# 	 - after brlen: logLH = -393014.412845
# Iteration 1: logLH = -393014.412845
# 	 - after rates: logLH = -393014.412845
# 	 - after freqs: logLH = -393014.412845
# 	 - after alpha: logLH = -393012.476580
# 	 - after p-inv: logLH = -393012.476580
# 	 - after freeR: logLH = -393012.476580
# 	 - after brlen: logLH = -393011.498989
# Iteration 2: logLH = -393011.498989
# [00:02:56 -393011.498989] FAST spr round 1 (radius: 15)
# 	 - after brlen: logLH = -367495.327935
# [00:03:06 -367495.327935] FAST spr round 2 (radius: 15)
# 	 - after brlen: logLH = -363625.313004
# [00:03:15 -363625.313004] FAST spr round 3 (radius: 15)
# 	 - after brlen: logLH = -329163.607937
# [00:03:23 -329163.607937] FAST spr round 4 (radius: 15)
# 	 - after brlen: logLH = -329073.046759
# [00:03:31 -329073.046759] FAST spr round 5 (radius: 15)
# 	 - after brlen: logLH = -329073.045785
# [00:03:39 -329073.045785] Model parameter optimization (eps = 1.000000)
# 	 - after rates: logLH = -329073.045785
# 	 - after freqs: logLH = -329073.045785
# 	 - after alpha: logLH = -328560.074520
# 	 - after p-inv: logLH = -328560.074520
# 	 - after freeR: logLH = -328560.074520
# 	 - after brlen: logLH = -328546.279689
# Iteration 1: logLH = -328546.279689
# 	 - after rates: logLH = -328546.279689
# 	 - after freqs: logLH = -328546.279689
# 	 - after alpha: logLH = -328546.079676
# 	 - after p-inv: logLH = -328546.079676
# 	 - after freeR: logLH = -328546.079676
# 	 - after brlen: logLH = -328546.034527
# Iteration 2: logLH = -328546.034527
# [00:03:40 -328546.034527] SLOW spr round 1 (radius: 5)
# 	 - after brlen: logLH = -328546.031897
# [00:03:55 -328546.031897] SLOW spr round 2 (radius: 10)
# 	 - after brlen: logLH = -328546.030825
# [00:04:06 -328546.030825] SLOW spr round 3 (radius: 15)
# 	 - after brlen: logLH = -328546.029749
# [00:04:07 -328546.029749] Model parameter optimization (eps = 0.100000)
# 	 - after rates: logLH = -328546.029749
# 	 - after freqs: logLH = -328546.029749
# 	 - after alpha: logLH = -328546.029749
# 	 - after p-inv: logLH = -328546.029749
# 	 - after freeR: logLH = -328546.029749
# 	 - after brlen: logLH = -328546.029211
# Iteration 1: logLH = -328546.029211
#
# [00:04:07] ML tree search #3, logLikelihood: -328546.029211
#
# [00:04:07 -720444.922184] Initial branch length optimization
# 	 - after brlen: logLH = -528039.181054
# [00:04:08 -528039.181054] Model parameter optimization (eps = 10.000000)
# 	 - after rates: logLH = -528039.181054
# 	 - after freqs: logLH = -528039.181054
# 	 - after alpha: logLH = -521557.716696
# 	 - after p-inv: logLH = -521557.716696
# 	 - after freeR: logLH = -521557.716696
# 	 - after brlen: logLH = -518162.393388
# Iteration 1: logLH = -518162.393388
# 	 - after rates: logLH = -518162.393388
# 	 - after freqs: logLH = -518162.393388
# 	 - after alpha: logLH = -517444.339639
# 	 - after p-inv: logLH = -517444.339639
# 	 - after freeR: logLH = -517444.339639
# 	 - after brlen: logLH = -516698.934455
# Iteration 2: logLH = -516698.934455
# 	 - after rates: logLH = -516698.934455
# 	 - after freqs: logLH = -516698.934455
# 	 - after alpha: logLH = -516281.278557
# 	 - after p-inv: logLH = -516281.278557
# 	 - after freeR: logLH = -516281.278557
# 	 - after brlen: logLH = -515894.740348
# Iteration 3: logLH = -515894.740348
# 	 - after rates: logLH = -515894.740348
# 	 - after freqs: logLH = -515894.740348
# 	 - after alpha: logLH = -515657.031395
# 	 - after p-inv: logLH = -515657.031395
# 	 - after freeR: logLH = -515657.031395
# 	 - after brlen: logLH = -515439.079380
# Iteration 4: logLH = -515439.079380
# 	 - after rates: logLH = -515439.079380
# 	 - after freqs: logLH = -515439.079380
# 	 - after alpha: logLH = -515305.920821
# 	 - after p-inv: logLH = -515305.920821
# 	 - after freeR: logLH = -515305.920821
# 	 - after brlen: logLH = -515173.540163
# Iteration 5: logLH = -515173.540163
# 	 - after rates: logLH = -515173.540163
# 	 - after freqs: logLH = -515173.540163
# 	 - after alpha: logLH = -515087.797429
# 	 - after p-inv: logLH = -515087.797429
# 	 - after freeR: logLH = -515087.797429
# 	 - after brlen: logLH = -515003.417443
# Iteration 6: logLH = -515003.417443
# 	 - after rates: logLH = -515003.417443
# 	 - after freqs: logLH = -515003.417443
# 	 - after alpha: logLH = -514946.207119
# 	 - after p-inv: logLH = -514946.207119
# 	 - after freeR: logLH = -514946.207119
# 	 - after brlen: logLH = -514891.490252
# Iteration 7: logLH = -514891.490252
# 	 - after rates: logLH = -514891.490252
# 	 - after freqs: logLH = -514891.490252
# 	 - after alpha: logLH = -514859.310433
# 	 - after p-inv: logLH = -514859.310433
# 	 - after freeR: logLH = -514859.310433
# 	 - after brlen: logLH = -514819.574100
# Iteration 8: logLH = -514819.574100
# 	 - after rates: logLH = -514819.574100
# 	 - after freqs: logLH = -514819.574100
# 	 - after alpha: logLH = -514795.826319
# 	 - after p-inv: logLH = -514795.826319
# 	 - after freeR: logLH = -514795.826319
# 	 - after brlen: logLH = -514766.747085
# Iteration 9: logLH = -514766.747085
# 	 - after rates: logLH = -514766.747085
# 	 - after freqs: logLH = -514766.747085
# 	 - after alpha: logLH = -514748.963249
# 	 - after p-inv: logLH = -514748.963249
# 	 - after freeR: logLH = -514748.963249
# 	 - after brlen: logLH = -514726.446259
# Iteration 10: logLH = -514726.446259
# 	 - after rates: logLH = -514726.446259
# 	 - after freqs: logLH = -514726.446259
# 	 - after alpha: logLH = -514713.091383
# 	 - after p-inv: logLH = -514713.091383
# 	 - after freeR: logLH = -514713.091383
# 	 - after brlen: logLH = -514696.647767
# Iteration 11: logLH = -514696.647767
# 	 - after rates: logLH = -514696.647767
# 	 - after freqs: logLH = -514696.647767
# 	 - after alpha: logLH = -514686.266758
# 	 - after p-inv: logLH = -514686.266758
# 	 - after freeR: logLH = -514686.266758
# 	 - after brlen: logLH = -514673.603176
# Iteration 12: logLH = -514673.603176
# 	 - after rates: logLH = -514673.603176
# 	 - after freqs: logLH = -514673.603176
# 	 - after alpha: logLH = -514665.511798
# 	 - after p-inv: logLH = -514665.511798
# 	 - after freeR: logLH = -514665.511798
# 	 - after brlen: logLH = -514657.279031
# Iteration 13: logLH = -514657.279031
# 	 - after rates: logLH = -514657.279031
# 	 - after freqs: logLH = -514657.279031
# 	 - after alpha: logLH = -514654.098270
# 	 - after p-inv: logLH = -514654.098270
# 	 - after freeR: logLH = -514654.098270
# 	 - after brlen: logLH = -514646.800132
# Iteration 14: logLH = -514646.800132
# 	 - after rates: logLH = -514646.800132
# 	 - after freqs: logLH = -514646.800132
# 	 - after alpha: logLH = -514643.990499
# 	 - after p-inv: logLH = -514643.990499
# 	 - after freeR: logLH = -514643.990499
# 	 - after brlen: logLH = -514637.782615
# Iteration 15: logLH = -514637.782615
# [00:04:20 -514637.782615] AUTODETECT spr round 1 (radius: 5)
# [00:04:24 -369687.117476] AUTODETECT spr round 2 (radius: 10)
# [00:04:25 -369685.761727] AUTODETECT spr round 3 (radius: 15)
# [00:04:26 -369685.182563] SPR radius for FAST iterations: 15 (autodetect)
# [00:04:26 -369685.182563] Model parameter optimization (eps = 3.000000)
# 	 - after rates: logLH = -369685.182563
# 	 - after freqs: logLH = -369685.182563
# 	 - after alpha: logLH = -367464.308409
# 	 - after p-inv: logLH = -367464.308409
# 	 - after freeR: logLH = -367464.308409
# 	 - after brlen: logLH = -367374.248455
# Iteration 1: logLH = -367374.248455
# 	 - after rates: logLH = -367374.248455
# 	 - after freqs: logLH = -367374.248455
# 	 - after alpha: logLH = -367373.308966
# 	 - after p-inv: logLH = -367373.308966
# 	 - after freeR: logLH = -367373.308966
# 	 - after brlen: logLH = -367372.655716
# Iteration 2: logLH = -367372.655716
# [00:04:27 -367372.655716] FAST spr round 1 (radius: 15)
# 	 - after brlen: logLH = -328873.020011
# [00:04:36 -328873.020011] FAST spr round 2 (radius: 15)
# 	 - after brlen: logLH = -328781.972186
# [00:04:44 -328781.972186] FAST spr round 3 (radius: 15)
# 	 - after brlen: logLH = -328734.474958
# [00:04:53 -328734.474958] FAST spr round 4 (radius: 15)
# 	 - after brlen: logLH = -328734.473552
# [00:05:00 -328734.473552] Model parameter optimization (eps = 1.000000)
# 	 - after rates: logLH = -328734.473552
# 	 - after freqs: logLH = -328734.473552
# 	 - after alpha: logLH = -328550.054951
# 	 - after p-inv: logLH = -328550.054951
# 	 - after freeR: logLH = -328550.054951
# 	 - after brlen: logLH = -328546.116689
# Iteration 1: logLH = -328546.116689
# 	 - after rates: logLH = -328546.116689
# 	 - after freqs: logLH = -328546.116689
# 	 - after alpha: logLH = -328546.083889
# 	 - after p-inv: logLH = -328546.083889
# 	 - after freeR: logLH = -328546.083889
# 	 - after brlen: logLH = -328546.072522
# Iteration 2: logLH = -328546.072522
# [00:05:02 -328546.072522] SLOW spr round 1 (radius: 5)
# 	 - after brlen: logLH = -328546.071090
# [00:05:16 -328546.071090] SLOW spr round 2 (radius: 10)
# 	 - after brlen: logLH = -328546.070004
# [00:05:28 -328546.070004] SLOW spr round 3 (radius: 15)
# 	 - after brlen: logLH = -328546.068920
# [00:05:28 -328546.068920] Model parameter optimization (eps = 0.100000)
# 	 - after rates: logLH = -328546.068920
# 	 - after freqs: logLH = -328546.068920
# 	 - after alpha: logLH = -328546.068920
# 	 - after p-inv: logLH = -328546.068920
# 	 - after freeR: logLH = -328546.068920
# 	 - after brlen: logLH = -328546.068379
# Iteration 1: logLH = -328546.068379
#
# [00:05:29] ML tree search #4, logLikelihood: -328546.068379
#
# [00:05:29 -719772.853513] Initial branch length optimization
# 	 - after brlen: logLH = -545067.385508
# [00:05:30 -545067.385508] Model parameter optimization (eps = 10.000000)
# 	 - after rates: logLH = -545067.385508
# 	 - after freqs: logLH = -545067.385508
# 	 - after alpha: logLH = -537149.528825
# 	 - after p-inv: logLH = -537149.528825
# 	 - after freeR: logLH = -537149.528825
# 	 - after brlen: logLH = -532755.985750
# Iteration 1: logLH = -532755.985750
# 	 - after rates: logLH = -532755.985750
# 	 - after freqs: logLH = -532755.985750
# 	 - after alpha: logLH = -532011.984171
# 	 - after p-inv: logLH = -532011.984171
# 	 - after freeR: logLH = -532011.984171
# 	 - after brlen: logLH = -531275.702101
# Iteration 2: logLH = -531275.702101
# 	 - after rates: logLH = -531275.702101
# 	 - after freqs: logLH = -531275.702101
# 	 - after alpha: logLH = -530850.091106
# 	 - after p-inv: logLH = -530850.091106
# 	 - after freeR: logLH = -530850.091106
# 	 - after brlen: logLH = -530458.243513
# Iteration 3: logLH = -530458.243513
# 	 - after rates: logLH = -530458.243513
# 	 - after freqs: logLH = -530458.243513
# 	 - after alpha: logLH = -530219.629900
# 	 - after p-inv: logLH = -530219.629900
# 	 - after freeR: logLH = -530219.629900
# 	 - after brlen: logLH = -529992.000161
# Iteration 4: logLH = -529992.000161
# 	 - after rates: logLH = -529992.000161
# 	 - after freqs: logLH = -529992.000161
# 	 - after alpha: logLH = -529843.496913
# 	 - after p-inv: logLH = -529843.496913
# 	 - after freeR: logLH = -529843.496913
# 	 - after brlen: logLH = -529703.766722
# Iteration 5: logLH = -529703.766722
# 	 - after rates: logLH = -529703.766722
# 	 - after freqs: logLH = -529703.766722
# 	 - after alpha: logLH = -529607.656704
# 	 - after p-inv: logLH = -529607.656704
# 	 - after freeR: logLH = -529607.656704
# 	 - after brlen: logLH = -529517.257817
# Iteration 6: logLH = -529517.257817
# 	 - after rates: logLH = -529517.257817
# 	 - after freqs: logLH = -529517.257817
# 	 - after alpha: logLH = -529452.508612
# 	 - after p-inv: logLH = -529452.508612
# 	 - after freeR: logLH = -529452.508612
# 	 - after brlen: logLH = -529392.239534
# Iteration 7: logLH = -529392.239534
# 	 - after rates: logLH = -529392.239534
# 	 - after freqs: logLH = -529392.239534
# 	 - after alpha: logLH = -529353.559411
# 	 - after p-inv: logLH = -529353.559411
# 	 - after freeR: logLH = -529353.559411
# 	 - after brlen: logLH = -529309.936695
# Iteration 8: logLH = -529309.936695
# 	 - after rates: logLH = -529309.936695
# 	 - after freqs: logLH = -529309.936695
# 	 - after alpha: logLH = -529281.448630
# 	 - after p-inv: logLH = -529281.448630
# 	 - after freeR: logLH = -529281.448630
# 	 - after brlen: logLH = -529249.436281
# Iteration 9: logLH = -529249.436281
# 	 - after rates: logLH = -529249.436281
# 	 - after freqs: logLH = -529249.436281
# 	 - after alpha: logLH = -529228.040662
# 	 - after p-inv: logLH = -529228.040662
# 	 - after freeR: logLH = -529228.040662
# 	 - after brlen: logLH = -529203.993822
# Iteration 10: logLH = -529203.993822
# 	 - after rates: logLH = -529203.993822
# 	 - after freqs: logLH = -529203.993822
# 	 - after alpha: logLH = -529187.674087
# 	 - after p-inv: logLH = -529187.674087
# 	 - after freeR: logLH = -529187.674087
# 	 - after brlen: logLH = -529169.313438
# Iteration 11: logLH = -529169.313438
# 	 - after rates: logLH = -529169.313438
# 	 - after freqs: logLH = -529169.313438
# 	 - after alpha: logLH = -529156.698867
# 	 - after p-inv: logLH = -529156.698867
# 	 - after freeR: logLH = -529156.698867
# 	 - after brlen: logLH = -529142.489495
# Iteration 12: logLH = -529142.489495
# 	 - after rates: logLH = -529142.489495
# 	 - after freqs: logLH = -529142.489495
# 	 - after alpha: logLH = -529132.629713
# 	 - after p-inv: logLH = -529132.629713
# 	 - after freeR: logLH = -529132.629713
# 	 - after brlen: logLH = -529122.956751
# Iteration 13: logLH = -529122.956751
# 	 - after rates: logLH = -529122.956751
# 	 - after freqs: logLH = -529122.956751
# 	 - after alpha: logLH = -529118.811478
# 	 - after p-inv: logLH = -529118.811478
# 	 - after freeR: logLH = -529118.811478
# 	 - after brlen: logLH = -529110.334960
# Iteration 14: logLH = -529110.334960
# 	 - after rates: logLH = -529110.334960
# 	 - after freqs: logLH = -529110.334960
# 	 - after alpha: logLH = -529106.679661
# 	 - after p-inv: logLH = -529106.679661
# 	 - after freeR: logLH = -529106.679661
# 	 - after brlen: logLH = -529099.523520
# Iteration 15: logLH = -529099.523520
# 	 - after rates: logLH = -529099.523520
# 	 - after freqs: logLH = -529099.523520
# 	 - after alpha: logLH = -529096.441653
# 	 - after p-inv: logLH = -529096.441653
# 	 - after freeR: logLH = -529096.441653
# 	 - after brlen: logLH = -529090.373843
# Iteration 16: logLH = -529090.373843
# [00:05:41 -529090.373843] AUTODETECT spr round 1 (radius: 5)
# [00:05:45 -393435.113722] AUTODETECT spr round 2 (radius: 10)
# [00:05:46 -393434.164395] AUTODETECT spr round 3 (radius: 15)
# [00:05:47 -393433.624037] SPR radius for FAST iterations: 15 (autodetect)
# [00:05:47 -393433.624037] Model parameter optimization (eps = 3.000000)
# 	 - after rates: logLH = -393433.624037
# 	 - after freqs: logLH = -393433.624037
# 	 - after alpha: logLH = -388741.562718
# 	 - after p-inv: logLH = -388741.562718
# 	 - after freeR: logLH = -388741.562718
# 	 - after brlen: logLH = -388641.482594
# Iteration 1: logLH = -388641.482594
# 	 - after rates: logLH = -388641.482594
# 	 - after freqs: logLH = -388641.482594
# 	 - after alpha: logLH = -388640.603098
# 	 - after p-inv: logLH = -388640.603098
# 	 - after freeR: logLH = -388640.603098
# 	 - after brlen: logLH = -388639.908579
# Iteration 2: logLH = -388639.908579
# [00:05:48 -388639.908579] FAST spr round 1 (radius: 15)
# 	 - after brlen: logLH = -363259.615872
# [00:05:58 -363259.615872] FAST spr round 2 (radius: 15)
# 	 - after brlen: logLH = -359192.130851
# [00:06:07 -359192.130851] FAST spr round 3 (radius: 15)
# 	 - after brlen: logLH = -329136.443557
# [00:06:16 -329136.443557] FAST spr round 4 (radius: 15)
# 	 - after brlen: logLH = -329136.133802
# [00:06:24 -329136.133802] Model parameter optimization (eps = 1.000000)
# 	 - after rates: logLH = -329136.133802
# 	 - after freqs: logLH = -329136.133802
# 	 - after alpha: logLH = -328562.377100
# 	 - after p-inv: logLH = -328562.377100
# 	 - after freeR: logLH = -328562.377100
# 	 - after brlen: logLH = -328546.342253
# Iteration 1: logLH = -328546.342253
# 	 - after rates: logLH = -328546.342253
# 	 - after freqs: logLH = -328546.342253
# 	 - after alpha: logLH = -328546.109510
# 	 - after p-inv: logLH = -328546.109510
# 	 - after freeR: logLH = -328546.109510
# 	 - after brlen: logLH = -328546.064183
# Iteration 2: logLH = -328546.064183
# [00:06:25 -328546.064183] SLOW spr round 1 (radius: 5)
# 	 - after brlen: logLH = -328546.061981
# [00:06:40 -328546.061981] SLOW spr round 2 (radius: 10)
# 	 - after brlen: logLH = -328546.060918
# [00:06:52 -328546.060918] SLOW spr round 3 (radius: 15)
# 	 - after brlen: logLH = -328546.059848
# [00:06:53 -328546.059848] Model parameter optimization (eps = 0.100000)
# 	 - after rates: logLH = -328546.059848
# 	 - after freqs: logLH = -328546.059848
# 	 - after alpha: logLH = -328546.059848
# 	 - after p-inv: logLH = -328546.059848
# 	 - after freeR: logLH = -328546.059848
# 	 - after brlen: logLH = -328546.059313
# Iteration 1: logLH = -328546.059313
#
# [00:06:53] ML tree search #5, logLikelihood: -328546.059313
#
# [00:06:53 -688168.752990] Initial branch length optimization
# 	 - after brlen: logLH = -532925.120345
# [00:06:54 -532925.120345] Model parameter optimization (eps = 10.000000)
# 	 - after rates: logLH = -532925.120345
# 	 - after freqs: logLH = -532925.120345
# 	 - after alpha: logLH = -525352.018643
# 	 - after p-inv: logLH = -525352.018643
# 	 - after freeR: logLH = -525352.018643
# 	 - after brlen: logLH = -521660.655460
# Iteration 1: logLH = -521660.655460
# 	 - after rates: logLH = -521660.655460
# 	 - after freqs: logLH = -521660.655460
# 	 - after alpha: logLH = -521153.349218
# 	 - after p-inv: logLH = -521153.349218
# 	 - after freeR: logLH = -521153.349218
# 	 - after brlen: logLH = -520626.780461
# Iteration 2: logLH = -520626.780461
# 	 - after rates: logLH = -520626.780461
# 	 - after freqs: logLH = -520626.780461
# 	 - after alpha: logLH = -520329.531238
# 	 - after p-inv: logLH = -520329.531238
# 	 - after freeR: logLH = -520329.531238
# 	 - after brlen: logLH = -520042.378966
# Iteration 3: logLH = -520042.378966
# 	 - after rates: logLH = -520042.378966
# 	 - after freqs: logLH = -520042.378966
# 	 - after alpha: logLH = -519871.016994
# 	 - after p-inv: logLH = -519871.016994
# 	 - after freeR: logLH = -519871.016994
# 	 - after brlen: logLH = -519696.956045
# Iteration 4: logLH = -519696.956045
# 	 - after rates: logLH = -519696.956045
# 	 - after freqs: logLH = -519696.956045
# 	 - after alpha: logLH = -519585.377260
# 	 - after p-inv: logLH = -519585.377260
# 	 - after freeR: logLH = -519585.377260
# 	 - after brlen: logLH = -519475.270115
# Iteration 5: logLH = -519475.270115
# 	 - after rates: logLH = -519475.270115
# 	 - after freqs: logLH = -519475.270115
# 	 - after alpha: logLH = -519400.334406
# 	 - after p-inv: logLH = -519400.334406
# 	 - after freeR: logLH = -519400.334406
# 	 - after brlen: logLH = -519327.770682
# Iteration 6: logLH = -519327.770682
# 	 - after rates: logLH = -519327.770682
# 	 - after freqs: logLH = -519327.770682
# 	 - after alpha: logLH = -519275.533685
# 	 - after p-inv: logLH = -519275.533685
# 	 - after freeR: logLH = -519275.533685
# 	 - after brlen: logLH = -519225.114554
# Iteration 7: logLH = -519225.114554
# 	 - after rates: logLH = -519225.114554
# 	 - after freqs: logLH = -519225.114554
# 	 - after alpha: logLH = -519194.029221
# 	 - after p-inv: logLH = -519194.029221
# 	 - after freeR: logLH = -519194.029221
# 	 - after brlen: logLH = -519156.907102
# Iteration 8: logLH = -519156.907102
# 	 - after rates: logLH = -519156.907102
# 	 - after freqs: logLH = -519156.907102
# 	 - after alpha: logLH = -519133.220905
# 	 - after p-inv: logLH = -519133.220905
# 	 - after freeR: logLH = -519133.220905
# 	 - after brlen: logLH = -519105.257055
# Iteration 9: logLH = -519105.257055
# 	 - after rates: logLH = -519105.257055
# 	 - after freqs: logLH = -519105.257055
# 	 - after alpha: logLH = -519087.022683
# 	 - after p-inv: logLH = -519087.022683
# 	 - after freeR: logLH = -519087.022683
# 	 - after brlen: logLH = -519065.273061
# Iteration 10: logLH = -519065.273061
# 	 - after rates: logLH = -519065.273061
# 	 - after freqs: logLH = -519065.273061
# 	 - after alpha: logLH = -519051.101750
# 	 - after p-inv: logLH = -519051.101750
# 	 - after freeR: logLH = -519051.101750
# 	 - after brlen: logLH = -519034.442055
# Iteration 11: logLH = -519034.442055
# 	 - after rates: logLH = -519034.442055
# 	 - after freqs: logLH = -519034.442055
# 	 - after alpha: logLH = -519023.222997
# 	 - after p-inv: logLH = -519023.222997
# 	 - after freeR: logLH = -519023.222997
# 	 - after brlen: logLH = -519010.100859
# Iteration 12: logLH = -519010.100859
# 	 - after rates: logLH = -519010.100859
# 	 - after freqs: logLH = -519010.100859
# 	 - after alpha: logLH = -519001.155702
# 	 - after p-inv: logLH = -519001.155702
# 	 - after freeR: logLH = -519001.155702
# 	 - after brlen: logLH = -518992.212157
# Iteration 13: logLH = -518992.212157
# 	 - after rates: logLH = -518992.212157
# 	 - after freqs: logLH = -518992.212157
# 	 - after alpha: logLH = -518988.473902
# 	 - after p-inv: logLH = -518988.473902
# 	 - after freeR: logLH = -518988.473902
# 	 - after brlen: logLH = -518980.496247
# Iteration 14: logLH = -518980.496247
# 	 - after rates: logLH = -518980.496247
# 	 - after freqs: logLH = -518980.496247
# 	 - after alpha: logLH = -518977.142504
# 	 - after p-inv: logLH = -518977.142504
# 	 - after freeR: logLH = -518977.142504
# 	 - after brlen: logLH = -518970.304391
# Iteration 15: logLH = -518970.304391
# 	 - after rates: logLH = -518970.304391
# 	 - after freqs: logLH = -518970.304391
# 	 - after alpha: logLH = -518967.419276
# 	 - after p-inv: logLH = -518967.419276
# 	 - after freeR: logLH = -518967.419276
# 	 - after brlen: logLH = -518961.549879
# Iteration 16: logLH = -518961.549879
# [00:07:04 -518961.549879] AUTODETECT spr round 1 (radius: 5)
# [00:07:08 -357275.404382] AUTODETECT spr round 2 (radius: 10)
# [00:07:10 -357271.766698] AUTODETECT spr round 3 (radius: 15)
# [00:07:10 -357271.672120] SPR radius for FAST iterations: 10 (autodetect)
# [00:07:11 -357271.672120] Model parameter optimization (eps = 3.000000)
# 	 - after rates: logLH = -357271.672120
# 	 - after freqs: logLH = -357271.672120
# 	 - after alpha: logLH = -355179.570305
# 	 - after p-inv: logLH = -355179.570305
# 	 - after freeR: logLH = -355179.570305
# 	 - after brlen: logLH = -355148.948660
# Iteration 1: logLH = -355148.948660
# 	 - after rates: logLH = -355148.948660
# 	 - after freqs: logLH = -355148.948660
# 	 - after alpha: logLH = -355148.290255
# 	 - after p-inv: logLH = -355148.290255
# 	 - after freeR: logLH = -355148.290255
# 	 - after brlen: logLH = -355148.085724
# Iteration 2: logLH = -355148.085724
# [00:07:12 -355148.085724] FAST spr round 1 (radius: 10)
# 	 - after brlen: logLH = -332081.884213
# [00:07:21 -332081.884213] FAST spr round 2 (radius: 10)
# 	 - after brlen: logLH = -331970.902725
# [00:07:30 -331970.902725] FAST spr round 3 (radius: 10)
# 	 - after brlen: logLH = -331970.671637
# [00:07:37 -331970.671637] Model parameter optimization (eps = 1.000000)
# 	 - after rates: logLH = -331970.671637
# 	 - after freqs: logLH = -331970.671637
# 	 - after alpha: logLH = -328806.506949
# 	 - after p-inv: logLH = -328806.506949
# 	 - after freeR: logLH = -328806.506949
# 	 - after brlen: logLH = -328550.736544
# Iteration 1: logLH = -328550.736544
# 	 - after rates: logLH = -328550.736544
# 	 - after freqs: logLH = -328550.736544
# 	 - after alpha: logLH = -328546.153543
# 	 - after p-inv: logLH = -328546.153543
# 	 - after freeR: logLH = -328546.153543
# 	 - after brlen: logLH = -328546.026860
# Iteration 2: logLH = -328546.026860
# 	 - after rates: logLH = -328546.026860
# 	 - after freqs: logLH = -328546.026860
# 	 - after alpha: logLH = -328546.026860
# 	 - after p-inv: logLH = -328546.026860
# 	 - after freeR: logLH = -328546.026860
# 	 - after brlen: logLH = -328546.016829
# Iteration 3: logLH = -328546.016829
# [00:07:39 -328546.016829] SLOW spr round 1 (radius: 5)
# 	 - after brlen: logLH = -328545.915646
# [00:07:55 -328545.915646] SLOW spr round 2 (radius: 10)
# 	 - after brlen: logLH = -328545.911609
# [00:08:07 -328545.911609] SLOW spr round 3 (radius: 15)
# 	 - after brlen: logLH = -328545.907591
# [00:08:08 -328545.907591] Model parameter optimization (eps = 0.100000)
# 	 - after rates: logLH = -328545.907591
# 	 - after freqs: logLH = -328545.907591
# 	 - after alpha: logLH = -328545.907591
# 	 - after p-inv: logLH = -328545.907591
# 	 - after freeR: logLH = -328545.907591
# 	 - after brlen: logLH = -328545.905590
# Iteration 1: logLH = -328545.905590
#
# [00:08:08] ML tree search #6, logLikelihood: -328545.905590
#
# [00:08:08 -723881.161082] Initial branch length optimization
# 	 - after brlen: logLH = -532563.520036
# [00:08:09 -532563.520036] Model parameter optimization (eps = 10.000000)
# 	 - after rates: logLH = -532563.520036
# 	 - after freqs: logLH = -532563.520036
# 	 - after alpha: logLH = -526583.353695
# 	 - after p-inv: logLH = -526583.353695
# 	 - after freeR: logLH = -526583.353695
# 	 - after brlen: logLH = -523669.561891
# Iteration 1: logLH = -523669.561891
# 	 - after rates: logLH = -523669.561891
# 	 - after freqs: logLH = -523669.561891
# 	 - after alpha: logLH = -523028.405228
# 	 - after p-inv: logLH = -523028.405228
# 	 - after freeR: logLH = -523028.405228
# 	 - after brlen: logLH = -522325.090017
# Iteration 2: logLH = -522325.090017
# 	 - after rates: logLH = -522325.090017
# 	 - after freqs: logLH = -522325.090017
# ...
# 	 - after freqs: logLH = -328614.170759
# 	 - after alpha: logLH = -328600.635198
# 	 - after p-inv: logLH = -328600.635198
# 	 - after freeR: logLH = -328600.635198
# 	 - after brlen: logLH = -328587.983396
# Iteration 9: logLH = -328587.983396
# 	 - after rates: logLH = -328587.983396
# 	 - after freqs: logLH = -328587.983396
# 	 - after alpha: logLH = -328577.139288
# 	 - after p-inv: logLH = -328577.139288
# 	 - after freeR: logLH = -328577.139288
# 	 - after brlen: logLH = -328566.977922
# Iteration 10: logLH = -328566.977922
# 	 - after rates: logLH = -328566.977922
# 	 - after freqs: logLH = -328566.977922
# 	 - after alpha: logLH = -328558.159745
# 	 - after p-inv: logLH = -328558.159745
# 	 - after freeR: logLH = -328558.159745
# 	 - after brlen: logLH = -328550.949445
# Iteration 11: logLH = -328550.949445
# 	 - after rates: logLH = -328550.949445
# 	 - after freqs: logLH = -328550.949445
# 	 - after alpha: logLH = -328547.906178
# 	 - after p-inv: logLH = -328547.906178
# 	 - after freeR: logLH = -328547.906178
# 	 - after brlen: logLH = -328547.877247
# Iteration 12: logLH = -328547.877247
# [00:19:23 -328547.877247] AUTODETECT spr round 1 (radius: 5)
# [00:19:26 -328546.089753] AUTODETECT spr round 2 (radius: 10)
# [00:19:27 -328546.088299] SPR radius for FAST iterations: 5 (autodetect)
# [00:19:27 -328546.088299] Model parameter optimization (eps = 3.000000)
# 	 - after rates: logLH = -328546.088299
# 	 - after freqs: logLH = -328546.088299
# 	 - after alpha: logLH = -328546.088299
# 	 - after p-inv: logLH = -328546.088299
# 	 - after freeR: logLH = -328546.088299
# 	 - after brlen: logLH = -328546.086851
# Iteration 1: logLH = -328546.086851
# [00:19:28 -328546.086851] FAST spr round 1 (radius: 5)
# 	 - after brlen: logLH = -328545.904749
# [00:19:34 -328545.904749] Model parameter optimization (eps = 1.000000)
# 	 - after rates: logLH = -328545.904749
# 	 - after freqs: logLH = -328545.904749
# 	 - after alpha: logLH = -328545.904749
# 	 - after p-inv: logLH = -328545.904749
# 	 - after freeR: logLH = -328545.904749
# 	 - after brlen: logLH = -328545.903995
# Iteration 1: logLH = -328545.903995
# [00:19:34 -328545.903995] SLOW spr round 1 (radius: 5)
# 	 - after brlen: logLH = -328545.883582
# [00:19:49 -328545.883582] SLOW spr round 2 (radius: 10)
# 	 - after brlen: logLH = -328545.882823
# [00:20:00 -328545.882823] SLOW spr round 3 (radius: 15)
# 	 - after brlen: logLH = -328545.882068
# [00:20:00 -328545.882068] Model parameter optimization (eps = 0.100000)
# 	 - after rates: logLH = -328545.882068
# 	 - after freqs: logLH = -328545.882068
# 	 - after alpha: logLH = -328545.882068
# 	 - after p-inv: logLH = -328545.882068
# 	 - after freeR: logLH = -328545.882068
# 	 - after brlen: logLH = -328545.881691
# Iteration 1: logLH = -328545.881691
#
# [00:20:00] ML tree search #18, logLikelihood: -328545.881691
#
# [00:20:01 -400289.077175] Initial branch length optimization
# 	 - after brlen: logLH = -330231.776936
# [00:20:01 -330231.776936] Model parameter optimization (eps = 10.000000)
# 	 - after rates: logLH = -330231.776936
# 	 - after freqs: logLH = -330231.776936
# 	 - after alpha: logLH = -329939.632448
# 	 - after p-inv: logLH = -329939.632448
# 	 - after freeR: logLH = -329939.632448
# 	 - after brlen: logLH = -329704.851535
# Iteration 1: logLH = -329704.851535
# 	 - after rates: logLH = -329704.851535
# 	 - after freqs: logLH = -329704.851535
# 	 - after alpha: logLH = -329538.532276
# 	 - after p-inv: logLH = -329538.532276
# 	 - after freeR: logLH = -329538.532276
# 	 - after brlen: logLH = -329398.947525
# Iteration 2: logLH = -329398.947525
# 	 - after rates: logLH = -329398.947525
# 	 - after freqs: logLH = -329398.947525
# 	 - after alpha: logLH = -329296.483052
# 	 - after p-inv: logLH = -329296.483052
# 	 - after freeR: logLH = -329296.483052
# 	 - after brlen: logLH = -329208.677396
# Iteration 3: logLH = -329208.677396
# 	 - after rates: logLH = -329208.677396
# 	 - after freqs: logLH = -329208.677396
# 	 - after alpha: logLH = -329142.341777
# 	 - after p-inv: logLH = -329142.341777
# 	 - after freeR: logLH = -329142.341777
# 	 - after brlen: logLH = -329083.972334
# Iteration 4: logLH = -329083.972334
# 	 - after rates: logLH = -329083.972334
# 	 - after freqs: logLH = -329083.972334
# 	 - after alpha: logLH = -329039.288566
# 	 - after p-inv: logLH = -329039.288566
# 	 - after freeR: logLH = -329039.288566
# 	 - after brlen: logLH = -328999.354632
# Iteration 5: logLH = -328999.354632
# 	 - after rates: logLH = -328999.354632
# 	 - after freqs: logLH = -328999.354632
# 	 - after alpha: logLH = -328967.850355
# 	 - after p-inv: logLH = -328967.850355
# 	 - after freeR: logLH = -328967.850355
# 	 - after brlen: logLH = -328939.269094
# Iteration 6: logLH = -328939.269094
# 	 - after rates: logLH = -328939.269094
# 	 - after freqs: logLH = -328939.269094
# 	 - after alpha: logLH = -328916.061975
# 	 - after p-inv: logLH = -328916.061975
# 	 - after freeR: logLH = -328916.061975
# 	 - after brlen: logLH = -328894.755967
# Iteration 7: logLH = -328894.755967
# 	 - after rates: logLH = -328894.755967
# 	 - after freqs: logLH = -328894.755967
# 	 - after alpha: logLH = -328877.025367
# 	 - after p-inv: logLH = -328877.025367
# 	 - after freeR: logLH = -328877.025367
# 	 - after brlen: logLH = -328860.616213
# Iteration 8: logLH = -328860.616213
# 	 - after rates: logLH = -328860.616213
# 	 - after freqs: logLH = -328860.616213
# 	 - after alpha: logLH = -328846.689757
# 	 - after p-inv: logLH = -328846.689757
# 	 - after freeR: logLH = -328846.689757
# 	 - after brlen: logLH = -328833.739457
# Iteration 9: logLH = -328833.739457
# 	 - after rates: logLH = -328833.739457
# 	 - after freqs: logLH = -328833.739457
# 	 - after alpha: logLH = -328822.579182
# 	 - after p-inv: logLH = -328822.579182
# 	 - after freeR: logLH = -328822.579182
# 	 - after brlen: logLH = -328812.174330
# Iteration 10: logLH = -328812.174330
# 	 - after rates: logLH = -328812.174330
# 	 - after freqs: logLH = -328812.174330
# 	 - after alpha: logLH = -328803.100523
# 	 - after p-inv: logLH = -328803.100523
# 	 - after freeR: logLH = -328803.100523
# 	 - after brlen: logLH = -328798.751354
# Iteration 11: logLH = -328798.751354
# 	 - after rates: logLH = -328798.751354
# 	 - after freqs: logLH = -328798.751354
# 	 - after alpha: logLH = -328798.056588
# 	 - after p-inv: logLH = -328798.056588
# 	 - after freeR: logLH = -328798.056588
# 	 - after brlen: logLH = -328798.032071
# Iteration 12: logLH = -328798.032071
# [00:20:08 -328798.032071] AUTODETECT spr round 1 (radius: 5)
# [00:20:11 -328546.296639] AUTODETECT spr round 2 (radius: 10)
# [00:20:12 -328546.259198] SPR radius for FAST iterations: 5 (autodetect)
# [00:20:12 -328546.259198] Model parameter optimization (eps = 3.000000)
# 	 - after rates: logLH = -328546.259198
# 	 - after freqs: logLH = -328546.259198
# 	 - after alpha: logLH = -328546.256941
# 	 - after p-inv: logLH = -328546.256941
# 	 - after freeR: logLH = -328546.256941
# 	 - after brlen: logLH = -328546.255225
# Iteration 1: logLH = -328546.255225
# [00:20:13 -328546.255225] FAST spr round 1 (radius: 5)
# 	 - after brlen: logLH = -328545.902003
# [00:20:19 -328545.902003] Model parameter optimization (eps = 1.000000)
# 	 - after rates: logLH = -328545.902003
# 	 - after freqs: logLH = -328545.902003
# 	 - after alpha: logLH = -328545.902003
# 	 - after p-inv: logLH = -328545.902003
# 	 - after freeR: logLH = -328545.902003
# 	 - after brlen: logLH = -328545.899989
# Iteration 1: logLH = -328545.899989
# [00:20:20 -328545.899989] SLOW spr round 1 (radius: 5)
# 	 - after brlen: logLH = -328545.739062
# [00:20:34 -328545.739062] SLOW spr round 2 (radius: 10)
# 	 - after brlen: logLH = -328545.739056
# [00:20:46 -328545.739056] SLOW spr round 3 (radius: 15)
# 	 - after brlen: logLH = -328545.739056
# [00:20:47 -328545.739056] Model parameter optimization (eps = 0.100000)
# 	 - after rates: logLH = -328545.739056
# 	 - after freqs: logLH = -328545.739056
# 	 - after alpha: logLH = -328545.739056
# 	 - after p-inv: logLH = -328545.739056
# 	 - after freeR: logLH = -328545.739056
# 	 - after brlen: logLH = -328545.739056
# Iteration 1: logLH = -328545.739056
#
# [00:20:47] ML tree search #19, logLikelihood: -328545.739056
#
# [00:20:47 -399846.801724] Initial branch length optimization
# 	 - after brlen: logLH = -330578.300094
# [00:20:47 -330578.300094] Model parameter optimization (eps = 10.000000)
# 	 - after rates: logLH = -330578.300094
# 	 - after freqs: logLH = -330578.300094
# 	 - after alpha: logLH = -330267.477340
# 	 - after p-inv: logLH = -330267.477340
# 	 - after freeR: logLH = -330267.477340
# 	 - after brlen: logLH = -330016.837489
# Iteration 1: logLH = -330016.837489
# 	 - after rates: logLH = -330016.837489
# 	 - after freqs: logLH = -330016.837489
# 	 - after alpha: logLH = -329842.311528
# 	 - after p-inv: logLH = -329842.311528
# 	 - after freeR: logLH = -329842.311528
# 	 - after brlen: logLH = -329694.318721
# Iteration 2: logLH = -329694.318721
# 	 - after rates: logLH = -329694.318721
# 	 - after freqs: logLH = -329694.318721
# 	 - after alpha: logLH = -329587.252951
# 	 - after p-inv: logLH = -329587.252951
# 	 - after freeR: logLH = -329587.252951
# 	 - after brlen: logLH = -329494.619958
# Iteration 3: logLH = -329494.619958
# 	 - after rates: logLH = -329494.619958
# 	 - after freqs: logLH = -329494.619958
# 	 - after alpha: logLH = -329425.513556
# 	 - after p-inv: logLH = -329425.513556
# 	 - after freeR: logLH = -329425.513556
# 	 - after brlen: logLH = -329364.196319
# Iteration 4: logLH = -329364.196319
# 	 - after rates: logLH = -329364.196319
# 	 - after freqs: logLH = -329364.196319
# 	 - after alpha: logLH = -329317.684833
# 	 - after p-inv: logLH = -329317.684833
# 	 - after freeR: logLH = -329317.684833
# 	 - after brlen: logLH = -329275.787505
# Iteration 5: logLH = -329275.787505
# 	 - after rates: logLH = -329275.787505
# 	 - after freqs: logLH = -329275.787505
# 	 - after alpha: logLH = -329242.950884
# 	 - after p-inv: logLH = -329242.950884
# 	 - after freeR: logLH = -329242.950884
# 	 - after brlen: logLH = -329212.952773
# Iteration 6: logLH = -329212.952773
# 	 - after rates: logLH = -329212.952773
# 	 - after freqs: logLH = -329212.952773
# 	 - after alpha: logLH = -329188.712113
# 	 - after p-inv: logLH = -329188.712113
# 	 - after freeR: logLH = -329188.712113
# 	 - after brlen: logLH = -329166.335420
# Iteration 7: logLH = -329166.335420
# 	 - after rates: logLH = -329166.335420
# 	 - after freqs: logLH = -329166.335420
# 	 - after alpha: logLH = -329147.784846
# 	 - after p-inv: logLH = -329147.784846
# 	 - after freeR: logLH = -329147.784846
# 	 - after brlen: logLH = -329130.552079
# Iteration 8: logLH = -329130.552079
# 	 - after rates: logLH = -329130.552079
# 	 - after freqs: logLH = -329130.552079
# 	 - after alpha: logLH = -329115.974466
# 	 - after p-inv: logLH = -329115.974466
# 	 - after freeR: logLH = -329115.974466
# 	 - after brlen: logLH = -329102.388645
# Iteration 9: logLH = -329102.388645
# 	 - after rates: logLH = -329102.388645
# 	 - after freqs: logLH = -329102.388645
# 	 - after alpha: logLH = -329090.714924
# 	 - after p-inv: logLH = -329090.714924
# 	 - after freeR: logLH = -329090.714924
# 	 - after brlen: logLH = -329080.639079
# Iteration 10: logLH = -329080.639079
# 	 - after rates: logLH = -329080.639079
# 	 - after freqs: logLH = -329080.639079
# 	 - after alpha: logLH = -329075.628640
# 	 - after p-inv: logLH = -329075.628640
# 	 - after freeR: logLH = -329075.628640
# 	 - after brlen: logLH = -329075.567558
# Iteration 11: logLH = -329075.567558
# [00:20:53 -329075.567558] AUTODETECT spr round 1 (radius: 5)
# [00:20:56 -328546.249711] AUTODETECT spr round 2 (radius: 10)
# [00:20:58 -328546.137354] AUTODETECT spr round 3 (radius: 15)
# [00:20:58 -328546.133278] SPR radius for FAST iterations: 10 (autodetect)
# [00:20:58 -328546.133278] Model parameter optimization (eps = 3.000000)
# 	 - after rates: logLH = -328546.133278
# 	 - after freqs: logLH = -328546.133278
# 	 - after alpha: logLH = -328546.056237
# 	 - after p-inv: logLH = -328546.056237
# 	 - after freeR: logLH = -328546.056237
# 	 - after brlen: logLH = -328546.053688
# Iteration 1: logLH = -328546.053688
# [00:20:59 -328546.053688] FAST spr round 1 (radius: 10)
# 	 - after brlen: logLH = -328545.881201
# [00:21:05 -328545.881201] Model parameter optimization (eps = 1.000000)
# 	 - after rates: logLH = -328545.881201
# 	 - after freqs: logLH = -328545.881201
# 	 - after alpha: logLH = -328545.881201
# 	 - after p-inv: logLH = -328545.881201
# 	 - after freeR: logLH = -328545.881201
# 	 - after brlen: logLH = -328545.880773
# Iteration 1: logLH = -328545.880773
# [00:21:05 -328545.880773] SLOW spr round 1 (radius: 5)
# 	 - after brlen: logLH = -328545.880022
# [00:21:20 -328545.880022] SLOW spr round 2 (radius: 10)
# 	 - after brlen: logLH = -328545.879274
# [00:21:33 -328545.879274] SLOW spr round 3 (radius: 15)
# 	 - after brlen: logLH = -328545.878527
# [00:21:33 -328545.878527] Model parameter optimization (eps = 0.100000)
# 	 - after rates: logLH = -328545.878527
# 	 - after freqs: logLH = -328545.878527
# 	 - after alpha: logLH = -328545.878527
# 	 - after p-inv: logLH = -328545.878527
# 	 - after freeR: logLH = -328545.878527
# 	 - after brlen: logLH = -328545.878154
# Iteration 1: logLH = -328545.878154
#
# [00:21:34] ML tree search #20, logLikelihood: -328545.878154
#
#
# Optimized model parameters:
#
#    Partition 0: noname
#    Rate heterogeneity: GAMMA (4 cats, mean),  alpha: 0.354165 (ML),  weights&rates: (0.250000,0.010695) (0.250000,0.146790) (0.250000,0.676507) (0.250000,3.166008)
#    Base frequencies (model): 0.079066 0.055941 0.041977 0.053052 0.012937 0.040767 0.071586 0.057337 0.022355 0.062157 0.099081 0.064600 0.022951 0.042302 0.044040 0.061197 0.053287 0.012066 0.034155 0.069147
#    Substitution rates (model): 0.425093 0.276818 0.395144 2.489084 0.969894 1.038545 2.066040 0.358858 0.149830 0.395337 0.536518 1.124035 0.253701 1.177651 4.727182 2.139501 0.180717 0.218959 2.547870 0.751878 0.123954 0.534551 2.807908 0.363970 0.390192 2.426601 0.126991 0.301848 6.326067 0.484133 0.052722 0.332533 0.858151 0.578987 0.593607 0.314440 0.170887 5.076149 0.528768 1.695752 0.541712 1.437645 4.509238 0.191503 0.068427 2.145078 0.371004 0.089525 0.161787 4.008358 2.000679 0.045376 0.612025 0.083688 0.062556 0.523386 5.243870 0.844926 0.927114 0.010690 0.015076 0.282959 0.025548 0.017416 0.394456 1.240275 0.425860 0.029890 0.135107 0.037967 0.084808 0.003499 0.569265 0.640543 0.320627 0.594007 0.013266 0.893680 1.105251 0.075382 2.784478 1.143480 0.670128 1.165532 1.959291 4.128591 0.267959 4.813505 0.072854 0.582457 3.234294 1.672569 0.035855 0.624294 1.223828 1.080136 0.236199 0.257336 0.210332 0.348847 0.423881 0.044265 0.069673 1.807177 0.173735 0.018811 0.419409 0.611973 0.604545 0.077852 0.120037 0.245034 0.311484 0.008705 0.044261 0.296636 0.139538 0.089586 0.196961 1.739990 0.129836 0.268491 0.054679 0.076701 0.108882 0.366317 0.697264 0.442472 0.682139 0.508851 0.990012 0.584262 0.597054 5.306834 0.119013 4.145067 0.159069 4.273607 1.112727 0.078281 0.064105 1.033739 0.111660 0.232523 10.649107 0.137500 6.312358 2.592692 0.249060 0.182287 0.302936 0.619632 0.299648 1.702745 0.656604 0.023918 0.390322 0.748683 1.136863 0.049906 0.131932 0.185202 1.798853 0.099849 0.346960 2.020366 0.696175 0.481306 1.898718 0.094464 0.361819 0.165001 2.457121 7.803902 0.654683 1.338132 0.571468 0.095131 0.089613 0.296501 6.472279 0.248862 0.400547 0.098369 0.140825 0.245841 2.188158 3.151815 0.189510 0.249313
#
#
# Final LogLikelihood: -328545.708777
#
# AIC score: 657151.417555 / AICc score: 657151.458288 / BIC score: 657413.309223
# Free parameters (model + branch lengths): 30
#
# WARNING: Best ML tree contains 1 near-zero branches!
#
# Best ML tree with collapsed near-zero branches saved to: /media/trungpq/Data/Code/Python/DH/Bio/phylogenetic-tree-reconstruction/T1.raxml.bestTreeCollapsed
# Best ML tree saved to: /media/trungpq/Data/Code/Python/DH/Bio/phylogenetic-tree-reconstruction/T1.raxml.bestTree
# All ML trees saved to: /media/trungpq/Data/Code/Python/DH/Bio/phylogenetic-tree-reconstruction/T1.raxml.mlTrees
# Optimized model saved to: /media/trungpq/Data/Code/Python/DH/Bio/phylogenetic-tree-reconstruction/T1.raxml.bestModel
#
# Execution log saved to: /media/trungpq/Data/Code/Python/DH/Bio/phylogenetic-tree-reconstruction/T1.raxml.log
#
# Analysis started: 09-May-2024 12:03:52 / finished: 09-May-2024 12:25:26
#
# Elapsed time: 1294.024 seconds

# %%
# !./bin/raxml-ng --bootstrap --msa T1.raxml.rba --model VT+G4+F --prefix T2 --threads 30 --bs-tree 300
# Out:
# RAxML-NG v. 1.2.2-master released on 30.04.2024 by The Exelixis Lab.
# Developed by: Alexey M. Kozlov and Alexandros Stamatakis.
# Contributors: Diego Darriba, Tomas Flouri, Benoit Morel, Sarah Lutteropp, Ben Bettisworth, Julia Haag, Anastasis Togkousidis.
# Latest version: https://github.com/amkozlov/raxml-ng
# Questions/problems/suggestions? Please visit: https://groups.google.com/forum/#!forum/raxml
#
# System: AMD Ryzen 7 5800H with Radeon Graphics, 8 cores, 14 GB RAM
#
# RAxML-NG was called at 09-May-2024 12:32:42 as follows:
#
# ./bin/raxml-ng --bootstrap --msa T1.raxml.rba --model LG+G4 --prefix T2 --threads 14 --bs-tree 1000
#
# Analysis options:
#   run mode: Bootstrapping
#   start tree(s):
#   bootstrap replicates: parsimony (1000)
#   random seed: 1715232762
#   tip-inner: OFF
#   pattern compression: ON
#   per-rate scalers: OFF
#   site repeats: ON
#   logLH epsilon: general: 0.100000, brlen-triplet: 1000.000000
#   fast spr radius: AUTO
#   spr subtree cutoff: 1.000000
#   fast CLV updates: ON
#   branch lengths: proportional (ML estimate, algorithm: NR-FAST)
#   SIMD kernels: AVX2
#   parallelization: coarse-grained (auto), PTHREADS (14 threads), thread pinning: OFF
#
# WARNING: The model you specified on the command line (LG+G4) will be ignored
#          since the binary MSA file already contains a model definition.
#          If you want to change the model, please re-run RAxML-NG
#          with the original PHYLIP/FASTA alignment and --redo option.
#
# [00:00:00] Loading binary alignment from file: T1.raxml.rba
# [00:00:00] Alignment comprises 16 taxa, 1 partitions and 16193 patterns
#
# Partition 0: noname
# Model: LG+G4m
# Alignment sites / patterns: 45694 / 16193
# Gaps: 43.84 %
# Invariant sites: 43.59 %
#
#
# Parallelization scheme autoconfig: 1 worker(s) x 14 thread(s)
#
# Parallel reduction/worker buffer size: 1 KB  / 0 KB
#
# [00:00:00] Data distribution: max. partitions/sites/weight per thread: 1 / 1157 / 92560
# [00:00:00] Data distribution: max. searches per worker: 1000
# [00:00:00] Starting bootstrapping analysis with 1000 replicates.
#
# [00:00:53] Bootstrap tree #1, logLikelihood: -328033.687707
# [00:01:58] Bootstrap tree #2, logLikelihood: -330960.958519
# [00:02:41] Bootstrap tree #3, logLikelihood: -327529.586470
# [00:03:32] Bootstrap tree #4, logLikelihood: -328164.608689
# [00:04:34] Bootstrap tree #5, logLikelihood: -328478.939708
# [00:05:11] Bootstrap tree #6, logLikelihood: -328159.198935
# [00:05:52] Bootstrap tree #7, logLikelihood: -330092.170813
# [00:06:30] Bootstrap tree #8, logLikelihood: -329653.872455
# [00:07:20] Bootstrap tree #9, logLikelihood: -330299.919851
# [00:08:09] Bootstrap tree #10, logLikelihood: -331048.119118
# [00:09:10] Bootstrap tree #11, logLikelihood: -328272.486856
# ^C

# %%
# !./bin/raxml-ng --support --tree T1.raxml.bestTree --bs-trees T2.raxml.bootstraps --prefix T3 --threads 30
# Out:
# /bin/bash: line 1: ./raxml-ng: No such file or directory

# %%
from io import StringIO

with open("T3.raxml.support", "r") as file:
    treedata = str(file.read())
    treedata = treedata.replace("data/genbank/", "")
    treedata = treedata.replace("_complete_genome", "")

    handle = StringIO(treedata)
    with open("best_tree.nh", "w") as ofile:
        ofile.write(treedata)

# %% [markdown]
# #  image generated with https://icytree.org/
# ![tree image](tree.png)
